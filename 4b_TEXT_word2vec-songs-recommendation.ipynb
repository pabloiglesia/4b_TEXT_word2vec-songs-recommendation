# %% [markdown]
# The aim of this notebook is to make use of the word2vec model to find similar songs

# %%
import pandas as pd
import numpy as np
import gensim.models.word2vec as w2v
import multiprocessing
import os
import re
import pprint
import sklearn.manifold
import matplotlib.pyplot as plt

# %% [markdown]
# # Limpieza y creación de los corpus

# %% [markdown]
# Though non english artists were removed, the dataset contained Hindi lyrics of Lata Mangeshkar written in English. Therefore, I decided to remove all songs sung by her.

# %%
import re

def normalize(s):
    replacements = (
        ("á", "a"),
        ("é", "e"),
        ("í", "i"),
        ("ó", "o"),
        ("ú", "u"),
        ("ñ", "n"),
    )
    for a, b in replacements:
        s = s.lower().replace(a, b)
    return s

def clean(text, remove_digits=True):
    if remove_digits:
        pattern = r'[^a-zA-z\s]'
    else:
        pattern=r'[^a-zA-z0-9\s]'
    text=re.sub(pattern,'',text).replace('\n', ' ')
    return text

# %% [markdown]
# ## Quijote

# %%
quijote = ['']
previous_line = ''
with open("data/quijote.txt", encoding='UTF-8') as f:
    for line in f:
        if line == '\n' and previous_line!='\n':
            quijote.append('')
        else:
            quijote[-1] = quijote[-1] + clean(normalize(line))
        previous_line = line

quijote_corpus = [[word for word in line.split()] for line in quijote if list != []]

print(len(quijote_corpus))
# Out:
# 5176

# %% [markdown]
# ## Rap
# Son canciones de rap en español. No es el mejor corpusm porque hay algunas canciones vacías, otras en inglés y catalán. Algunos artistas mezclan español con inglés, y suele haber faltas de ortografía.

# %%
songs = pd.read_csv("data/hhgroups_merge_28_05.csv", header=0)
rap_corpus = [[word for word in clean(normalize(line)).split()] for line in songs['letra']]
print(len(rap_corpus))
# Out:
# 9325

# %% [markdown]
# ## Noticias
# Corpus compuesto por más de 500 noticias extraidas del diario El Mundo utilizando el fichero get_news.py. Estas noticias corresponden a 8 secciones diferentes.
# Este corpus es demasiado pequeño para que salgan cosas razonables en la sección de análisis de palabras similares, pero será útil para realizar clustering sobre él.

# %%
news = pd.read_csv("data/noticias.csv", sep='\|', encoding='UTF-8').groupby('NEW_TITLE', as_index=False).max()
news_corpus = [[word for word in clean(normalize(str(line))).split()] for line in news['NEW']]
print(len(news_corpus))
# Out:
# 542

# %% [markdown]
# ## Los tres juntos

# %%
join_corpus = quijote_corpus + rap_corpus + news_corpus
print(len(join_corpus))
# Out:
# 15043

# %% [markdown]
# # Entrenamiento de los modelos

# %% [markdown]
# ### Parámetros utilizados en el entrenamiento

# %%
# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 100
# Minimum word count threshold.
min_word_count = 10

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7


downsampling = 1e-1

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %% [markdown]
# ## Rap

# %%
songs2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

songs2vec.build_vocab(rap_corpus)
print (len(rap_corpus))
# Out:
# 9325

# %%
import time
start_time = time.time()

songs2vec.train(rap_corpus, total_examples=songs2vec.corpus_count, epochs=20)

if not os.path.exists("trained"):
    os.makedirs("trained")

songs2vec.save(os.path.join("trained", "songs2vectors.w2v"))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 308.18955993652344 seconds ---

# %% [markdown]
# ## Quijote

# %%
quijote2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

quijote2vec.build_vocab(quijote_corpus)
print (len(quijote_corpus))
# Out:
# 5176

# %%
import time
start_time = time.time()

quijote2vec.train(quijote_corpus, total_examples=quijote2vec.corpus_count, epochs=20)

if not os.path.exists("trained"):
    os.makedirs("trained")

quijote2vec.save(os.path.join("trained", "quijote2vectors.w2v"))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 28.54300093650818 seconds ---

# %% [markdown]
# ## Noticias
# En este caso utilizamos un min_count de 2, porque el corpus es demasiado pequeño, y si se descartan más palabras no se podrá comparar con los otros corpus.m

# %%
news2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=2,
    window=context_size,
    sample=downsampling
)

news2vec.build_vocab(news_corpus)
print (len(news_corpus))
# Out:
# 542

# %%
import time
start_time = time.time()

news2vec.train(news_corpus, total_examples=news2vec.corpus_count, epochs=20)

if not os.path.exists("trained"):
    os.makedirs("trained")

news2vec.save(os.path.join("trained", "news2vectors.w2v"))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 19.259528875350952 seconds ---

# %% [markdown]
# ## Los tres juntos

# %%
join2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

join2vec.build_vocab(join_corpus)
print (len(join_corpus))
# Out:
# 15043

# %%
import time
start_time = time.time()

join2vec.train(join_corpus, total_examples=join2vec.corpus_count, epochs=20)

if not os.path.exists("trained"):
    os.makedirs("trained")

join2vec.save(os.path.join("trained", "join2vectors.w2v"))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 355.69666147232056 seconds ---

# %% [markdown]
# ## Se cargan los modelos

# %%
songs2vec = w2v.Word2Vec.load(os.path.join("trained", "songs2vectors.w2v"))

# %%
quijote2vec = w2v.Word2Vec.load(os.path.join("trained", "quijote2vectors.w2v"))

# %%
join2vec = w2v.Word2Vec.load(os.path.join("trained", "join2vectors.w2v"))

# %%
news2vec = w2v.Word2Vec.load(os.path.join("trained", "news2vectors.w2v"))

# %% [markdown]
# # Comparación de los resultados

# %% [markdown]
# ## Palabras similares

# %% [markdown]
# ### Amor

# %%
rap = [word[0] for word in songs2vec.wv.most_similar("amor")]
quijote = [word[0] for word in quijote2vec.wv.most_similar("amor")]
join = [word[0] for word in join2vec.wv.most_similar("amor")]
news = [word[0] for word in news2vec.wv.most_similar("amor")]
pd.DataFrame(list(zip(rap,quijote,join,news)), columns =['Rap', 'Quijote', 'Juntos', 'Noticias'])
# Out:
#          Rap       Quijote     Juntos    Noticias
# 0      dolor        premio      dolor   intentaba
# 1       odio      vergenza       odio       vivio
# 2     rencor  misericordia     rencor      espejo
# 3     carino        recato    desamor     tactica
# 4  verdadero     solicitud  platonico  homosexual
# 5  platonico         trato     carino       huido
# 6    desamor      alabanza       sexo      marcel
# 7      honor          nace     olvido       llaga
# 8     placer      quitarme      calor      amante
# 9    amistad       muestre  verdadero       novio

# %% [markdown]
# ### Iglesia

# %%
rap = [word[0] for word in songs2vec.wv.most_similar("iglesia")]
quijote = [word[0] for word in quijote2vec.wv.most_similar("iglesia")]
join = [word[0] for word in join2vec.wv.most_similar("iglesia")]
news = [word[0] for word in news2vec.wv.most_similar("iglesia")]
pd.DataFrame(list(zip(rap,quijote,join,news)), columns =['Rap', 'Quijote', 'Juntos', 'Noticias'])
# Out:
#           Rap       Quijote       Juntos       Noticias
# 0      biblia         santa     catolica        unanime
# 1    politica     hermandad       biblia   alimentacion
# 2       madre       riqueza       romana            ajo
# 3    hambruna  misericordia     justicia  contemporaneo
# 4  injusticia         honra     zarzuela          finca
# 5      romana         corte     politica        aplauso
# 6    impuesta         madre  inquisicion         conejo
# 7    economia       miseria     hacienda         cuadro
# 8     pobreza          dada   obediencia        juvenil
# 9   poblacion      hacienda    monarquia          luces

# %% [markdown]
# ### Bella

# %%
rap = [word[0] for word in songs2vec.wv.most_similar("bella")]
quijote = [word[0] for word in quijote2vec.wv.most_similar("bella")]
join = [word[0] for word in join2vec.wv.most_similar("bella")]
news = [word[0] for word in news2vec.wv.most_similar("bella")]
pd.DataFrame(list(zip(rap,quijote,join,news)), columns =['Rap', 'Quijote', 'Juntos', 'Noticias'])
# Out:
#         Rap    Quijote    Juntos       Noticias
# 0   hermosa   criatura   hermosa        clasica
# 1    bonita    enemiga    bonita        claudia
# 2  preciosa    hermosa     linda     misteriosa
# 3  sencilla      amada  preciosa          turco
# 4  princesa    dichoso      dama    reflectante
# 5  discreta    belerma   pequena  esencialmente
# 6     linda    ingrata       fea        ternura
# 7    oscura  labradora  princesa      romantica
# 8   pequena    querida    mustia         traida
# 9      ella    cautiva     diosa         fisura

# %% [markdown]
# ### Gobierno

# %%
rap = [word[0] for word in songs2vec.wv.most_similar("gobierno")]
quijote = [word[0] for word in quijote2vec.wv.most_similar("gobierno")]
join = [word[0] for word in join2vec.wv.most_similar("gobierno")]
news = [word[0] for word in news2vec.wv.most_similar("gobierno")]
pd.DataFrame(list(zip(rap,quijote,join,news)), columns =['Rap', 'Quijote', 'Juntos', 'Noticias'])
# Out:
#            Rap     Quijote      Juntos         Noticias
# 0       pueblo      insula  presidente        ejecutivo
# 1      sistema  gobernador   ejecutivo          sanchez
# 2     dictador   barataria    ministro           empeno
# 3     policial   prometida        cgpj       anticipado
# 4        ebola     condado  ministerio    racionamiento
# 5     politico         dia     sanidad       gobernador
# 6  capitalista       aviso         erc  socialcomunista
# 7   organizado   prometido  comunicado               pp
# 8     congreso      traves         pnv      hansjoachim
# 9   presidente    posesion    portavoz        criticado

# %% [markdown]
# Los resultados de este análisis son mejorables, pero se observa que en todas las palabras se obtienen palabras relacionadas con la palabra objetivo, menos con el Corpus de noticias, que es demasiado pequeño. Se observa que que el corpus de noticias sí que funciona correctamente para la palabra gobierno, debido a que es una palabra que se repite mucho en las noticias de actualidad.

# %% [markdown]
# ## Palabras fuera de contexto

# %% [markdown]
# ### perro gato pajaro armario

# %%
palabras = "perro gato pajaro armario".split()

rap = songs2vec.wv.doesnt_match(palabras)
quijote = quijote2vec.wv.doesnt_match(palabras)
join = join2vec.wv.doesnt_match(palabras)
news = news2vec.wv.doesnt_match(palabras)

print("Con el corpus de rap sobra: {}".format(rap))
print("Con el corpus de quijote sobra: {}".format(quijote))
print("Con el corpus de join sobra: {}".format(join))
print("Con el corpus de noticias sobra: {}".format(news))
# Out:
# Con el corpus de rap sobra: armario
# Con el corpus de quijote sobra: gato
# Con el corpus de join sobra: armario
# Con el corpus de noticias sobra: pajaro

# %% [markdown]
# ### cojin sofa mesa arbol

# %%
palabras = "cojin sofa mesa arbol".split()

rap = songs2vec.wv.doesnt_match(palabras)
quijote = quijote2vec.wv.doesnt_match(palabras)
join = join2vec.wv.doesnt_match(palabras)
news = news2vec.wv.doesnt_match(palabras)

print("Con el corpus de rap sobra: {}".format(rap))
print("Con el corpus de quijote sobra: {}".format(quijote))
print("Con el corpus de join sobra: {}".format(join))
print("Con el corpus de noticias sobra: {}".format(news))
# Out:
# Con el corpus de rap sobra: arbol
# Con el corpus de quijote sobra: mesa
# Con el corpus de join sobra: cojin
# Con el corpus de noticias sobra: sofa

# %% [markdown]
# ## Regla de 3

# %% [markdown]
# ### Hombre, Reina | Mujer --> ?

# %%
positive = ['hombre', 'reina']
negative = ['mujer']

rap = [word[0] for word in songs2vec.most_similar(positive=positive, negative=negative)]
quijote = [word[0] for word in quijote2vec.most_similar(positive=positive, negative=negative)]
join = [word[0] for word in join2vec.most_similar(positive=positive, negative=negative)]
news = [word[0] for word in news2vec.most_similar(positive=positive, negative=negative)]
pd.DataFrame(list(zip(rap,quijote,join,news)), columns =['Rap', 'Quijote', 'Juntos', 'Noticias'])
#queen
# Out:
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
#
# Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
#
# Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning:
#
# Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#           Rap    Quijote     Juntos     Noticias
# 0         rey   principe        rey         tuit
# 1       reino     roldan    imperio  colaborador
# 2       reyes  caballero     faraon     estomago
# 3        lobo  encantado    apodado     diputada
# 4     creador        feo   artifice        sello
# 5     tsunami     pintor        zar     difundir
# 6  estandarte    maestro  gladiador       acabar
# 7      relata    pierres   pacifico   anunciaban
# 8       yeaah      viene     relata   implacable
# 9   gladiador    soldado   poseidon        ayudo

# %% [markdown]
# ## Distancia entre palabras

# %%
def nearest_similarity_cosmul(vec, start1, end1, end2, prefix=''):
    similarities = vec.wv.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{4}{0} es a {1}, lo que {2} es a {3}".format(start1, end1, start2, end2, prefix))

# %% [markdown]
# ### "noche", "dia", "arriba"

# %%
start1 = "noche"
start2 = "dia"
end1 = "arriba"

nearest_similarity_cosmul(songs2vec, start1, start2, end1, 'Rap: ')
nearest_similarity_cosmul(quijote2vec, start1, start2, end1, 'Quijote: ')
nearest_similarity_cosmul(join2vec, start1, start2, end1, 'Juntos: ')
nearest_similarity_cosmul(news2vec, start1, start2, end1, 'Juntos: ')
# Out:
# Rap: noche es a dia, lo que cima es a arriba
# Quijote: noche es a dia, lo que abajo es a arriba
# Juntos: noche es a dia, lo que abajo es a arriba
# Juntos: noche es a dia, lo que sara es a arriba

# %% [markdown]
# # Clustering

# %%
def create_vector(row):
    vector_sum = 0
    words = row.lower().split()
    for word in words:
        try:
            vector_sum = vector_sum + songs2vec[word]
        except:
            pass
    if isinstance(vector_sum, int):
        return "No words in vocab"
    else:
        vector_sum = vector_sum.reshape(1,-1)
    normalised_vector_sum = sklearn.preprocessing.normalize(vector_sum)

    return normalised_vector_sum

# %% [markdown]
# ## Clustering de canciones 2D

# %%
import time
start_time = time.time()

songs['song_vector'] = [clean(normalize(letra)) for letra in songs['letra']]
songs['song_vector'] = songs['song_vector'].apply(create_vector)
songs = songs[songs['song_vector'] != "No words in vocab"]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#  self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# --- 35.560264348983765 seconds ---
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# ### t-sne and random song selection

# %%
song_vectors = []
from sklearn.model_selection import train_test_split

train, test = train_test_split(songs, test_size = 0.2)


for song_vector in train['song_vector']:
    song_vectors.append(song_vector)

train.head(10)
# Out:
#       id                artista                              cancion  \
# 7731   1  Ceerre y Pablo Gareta                             Concepto
# 6922  17                Hard GZ                              Monster
# 5278  23                  Dante                                Calma
# 6959  54                   SFDK                           Lo intento
# 413   28                   SFDK  Seguimos fuertes (con Jefe de la M)
# 6333  33        Omar El Hachemi                        Breaking news
# 5579  49           Gordo Master     El paraiso nos rodea (con Raule)
# 8286   6                   Momo                               Viento
# 8326  46             Iván Nieto                               Hambre
# 5981  11        Riot propaganda                       Cambiarlo todo
#
#                               album  \
# 7731                    Grey theory
# 6922                     Nictofilia
# 5278  Sin álbum, es un vídeo suelto
# 6959              Tesoros y caras B
# 413               Siempre fuertes 2
# 6333                        Apolo 8
# 5579                      Freshkush
# 8286                         Viento
# 8326                   Mirlo blanco
# 5981                  Agenda oculta
#
#                                                   letra  anyo  visitas  \
# 7731  [Ceerre]\nCon esta presión dentro desde pequeñ...  2015     1229
# 6922  Cada día me acuerdo de cuando tenía 6 años,\nf...  2015     6032
# 5278  Ahora voy a hablar, pa' dejar las cosas claras...  2017     8173
# 6959  Tú di, tú di, jefe de la M, ?ok?,\nespecial de...  2010     1037
# 413   [Estribillo]\nSuenan Jefe y SFDK\nsi no siente...  2009     3408
# 6333  El banco es el trono de ese borracho,\nLa barr...  2016      313
# 5579  [Gordo Master]\nCon mi música me siento libre,...  2017      531
# 8286  [Estribillo] (x4)\nV-I-E-N-T-O.\nViento.\n\nEm...  2013      947
# 8326  Cambio de chaqueta porque ahora sea moda,\nsi ...  2014     1885
# 5981  [Nega]\nA lomos de un Airbus, La Mazorca, Habe...  2017     4105
#
#                                             song_vector
# 7731  [[-0.034195747, 0.09055399, 0.1346869, -0.1285...
# 6922  [[-0.033740018, 0.10971237, 0.14973374, -0.174...
# 5278  [[-0.05179523, 0.103807546, 0.16787839, -0.209...
# 6959  [[-0.025074981, 0.09681175, 0.1696142, -0.1441...
# 413   [[-0.04357646, 0.09102699, 0.1567576, -0.14719...
# 6333  [[-0.04542916, 0.1002035, 0.15871415, -0.16521...
# 5579  [[-0.020846864, 0.08475931, 0.106602, -0.13565...
# 8286  [[-0.070750564, 0.0592482, 0.14344029, -0.2086...
# 8326  [[-0.042250436, 0.08705383, 0.14074238, -0.196...
# 5981  [[-0.054960012, 0.10092814, 0.20124944, -0.160...

# %%
X = np.array(song_vectors).reshape((int(len(song_vectors)*num_features/num_features), num_features))

start_time = time.time()
tsne = sklearn.manifold.TSNE(n_components=2, n_iter=10000, random_state=0, verbose=10)

all_word_vectors_matrix_2d = tsne.fit_transform(X)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 7459 samples in 0.286s...
# [t-SNE] Computed neighbors for 7459 samples in 20.559s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7459
# [t-SNE] Computed conditional probabilities for sample 2000 / 7459
# [t-SNE] Computed conditional probabilities for sample 3000 / 7459
# [t-SNE] Computed conditional probabilities for sample 4000 / 7459
# [t-SNE] Computed conditional probabilities for sample 5000 / 7459
# [t-SNE] Computed conditional probabilities for sample 6000 / 7459
# [t-SNE] Computed conditional probabilities for sample 7000 / 7459
# [t-SNE] Computed conditional probabilities for sample 7459 / 7459
# [t-SNE] Mean sigma: 0.053211
# [t-SNE] Computed conditional probabilities in 0.490s
# [t-SNE] Iteration 50: error = 89.6782990, gradient norm = 0.0762581 (50 iterations in 6.507s)
# [t-SNE] Iteration 100: error = 89.0150452, gradient norm = 0.0359127 (50 iterations in 4.103s)
# [t-SNE] Iteration 150: error = 88.9644775, gradient norm = 0.0532429 (50 iterations in 4.222s)
# [t-SNE] Iteration 200: error = 88.6540604, gradient norm = 0.0426760 (50 iterations in 3.721s)
# [t-SNE] Iteration 250: error = 88.8164139, gradient norm = 0.0463993 (50 iterations in 3.530s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 88.816414
# [t-SNE] Iteration 300: error = 3.4490304, gradient norm = 0.0011585 (50 iterations in 4.484s)
# [t-SNE] Iteration 350: error = 3.2014830, gradient norm = 0.0004688 (50 iterations in 3.696s)
# [t-SNE] Iteration 400: error = 3.1075325, gradient norm = 0.0002501 (50 iterations in 3.782s)
# [t-SNE] Iteration 450: error = 3.0531800, gradient norm = 0.0001630 (50 iterations in 4.112s)
# [t-SNE] Iteration 500: error = 3.0171051, gradient norm = 0.0001204 (50 iterations in 3.787s)
# [t-SNE] Iteration 550: error = 2.9916024, gradient norm = 0.0000942 (50 iterations in 4.145s)
# [t-SNE] Iteration 600: error = 2.9728229, gradient norm = 0.0000817 (50 iterations in 3.889s)
# [t-SNE] Iteration 650: error = 2.9591455, gradient norm = 0.0000722 (50 iterations in 3.846s)
# [t-SNE] Iteration 700: error = 2.9488935, gradient norm = 0.0000614 (50 iterations in 3.859s)
# [t-SNE] Iteration 750: error = 2.9405670, gradient norm = 0.0000559 (50 iterations in 3.976s)
# [t-SNE] Iteration 800: error = 2.9342582, gradient norm = 0.0000496 (50 iterations in 3.884s)
# [t-SNE] Iteration 850: error = 2.9287925, gradient norm = 0.0000447 (50 iterations in 4.025s)
# [t-SNE] Iteration 900: error = 2.9240639, gradient norm = 0.0000423 (50 iterations in 4.131s)
# [t-SNE] Iteration 950: error = 2.9202712, gradient norm = 0.0000396 (50 iterations in 4.093s)
# [t-SNE] Iteration 1000: error = 2.9171152, gradient norm = 0.0000377 (50 iterations in 3.922s)
# [t-SNE] Iteration 1050: error = 2.9145226, gradient norm = 0.0000366 (50 iterations in 4.156s)
# [t-SNE] Iteration 1100: error = 2.9124768, gradient norm = 0.0000332 (50 iterations in 4.102s)
# [t-SNE] Iteration 1150: error = 2.9104862, gradient norm = 0.0000304 (50 iterations in 3.980s)
# [t-SNE] Iteration 1200: error = 2.9085443, gradient norm = 0.0000309 (50 iterations in 4.241s)
# [t-SNE] Iteration 1250: error = 2.9067786, gradient norm = 0.0000287 (50 iterations in 4.001s)
# [t-SNE] Iteration 1300: error = 2.9052389, gradient norm = 0.0000276 (50 iterations in 4.089s)
# [t-SNE] Iteration 1350: error = 2.9038627, gradient norm = 0.0000276 (50 iterations in 4.169s)
# [t-SNE] Iteration 1400: error = 2.9027593, gradient norm = 0.0000287 (50 iterations in 4.057s)
# [t-SNE] Iteration 1450: error = 2.9018822, gradient norm = 0.0000265 (50 iterations in 3.693s)
# [t-SNE] Iteration 1500: error = 2.9010892, gradient norm = 0.0000273 (50 iterations in 4.026s)
# [t-SNE] Iteration 1550: error = 2.9003696, gradient norm = 0.0000252 (50 iterations in 4.147s)
# [t-SNE] Iteration 1600: error = 2.8996832, gradient norm = 0.0000240 (50 iterations in 3.969s)
# [t-SNE] Iteration 1650: error = 2.8989587, gradient norm = 0.0000230 (50 iterations in 3.761s)
# [t-SNE] Iteration 1700: error = 2.8983054, gradient norm = 0.0000226 (50 iterations in 4.117s)
# [t-SNE] Iteration 1750: error = 2.8976297, gradient norm = 0.0000217 (50 iterations in 3.952s)
# [t-SNE] Iteration 1800: error = 2.8969476, gradient norm = 0.0000203 (50 iterations in 3.421s)
# [t-SNE] Iteration 1850: error = 2.8962779, gradient norm = 0.0000204 (50 iterations in 3.744s)
# [t-SNE] Iteration 1900: error = 2.8956077, gradient norm = 0.0000183 (50 iterations in 3.832s)
# [t-SNE] Iteration 1950: error = 2.8949840, gradient norm = 0.0000190 (50 iterations in 3.767s)
# [t-SNE] Iteration 2000: error = 2.8944182, gradient norm = 0.0000198 (50 iterations in 3.919s)
# [t-SNE] Iteration 2050: error = 2.8939123, gradient norm = 0.0000182 (50 iterations in 3.951s)
# [t-SNE] Iteration 2100: error = 2.8934085, gradient norm = 0.0000186 (50 iterations in 3.703s)
# [t-SNE] Iteration 2150: error = 2.8929229, gradient norm = 0.0000178 (50 iterations in 3.909s)
# [t-SNE] Iteration 2200: error = 2.8924670, gradient norm = 0.0000181 (50 iterations in 3.778s)
# [t-SNE] Iteration 2250: error = 2.8919749, gradient norm = 0.0000179 (50 iterations in 3.656s)
# [t-SNE] Iteration 2300: error = 2.8916473, gradient norm = 0.0000182 (50 iterations in 4.167s)
# [t-SNE] Iteration 2350: error = 2.8911927, gradient norm = 0.0000198 (50 iterations in 3.963s)
# [t-SNE] Iteration 2400: error = 2.8908863, gradient norm = 0.0000172 (50 iterations in 4.067s)
# [t-SNE] Iteration 2450: error = 2.8906114, gradient norm = 0.0000159 (50 iterations in 4.064s)
# [t-SNE] Iteration 2500: error = 2.8903542, gradient norm = 0.0000167 (50 iterations in 4.563s)
# [t-SNE] Iteration 2550: error = 2.8900468, gradient norm = 0.0000177 (50 iterations in 4.407s)
# [t-SNE] Iteration 2600: error = 2.8898003, gradient norm = 0.0000192 (50 iterations in 4.534s)
# [t-SNE] Iteration 2650: error = 2.8895941, gradient norm = 0.0000195 (50 iterations in 4.825s)
# [t-SNE] Iteration 2700: error = 2.8894711, gradient norm = 0.0000194 (50 iterations in 4.936s)
# [t-SNE] Iteration 2750: error = 2.8892763, gradient norm = 0.0000172 (50 iterations in 4.086s)
# [t-SNE] Iteration 2800: error = 2.8891125, gradient norm = 0.0000155 (50 iterations in 4.044s)
# [t-SNE] Iteration 2850: error = 2.8889365, gradient norm = 0.0000146 (50 iterations in 3.946s)
# [t-SNE] Iteration 2900: error = 2.8887534, gradient norm = 0.0000157 (50 iterations in 4.149s)
# [t-SNE] Iteration 2950: error = 2.8885331, gradient norm = 0.0000167 (50 iterations in 4.220s)
# [t-SNE] Iteration 3000: error = 2.8883634, gradient norm = 0.0000153 (50 iterations in 4.108s)
# [t-SNE] Iteration 3050: error = 2.8881965, gradient norm = 0.0000145 (50 iterations in 4.346s)
# [t-SNE] Iteration 3100: error = 2.8879657, gradient norm = 0.0000145 (50 iterations in 4.451s)
# [t-SNE] Iteration 3150: error = 2.8876839, gradient norm = 0.0000147 (50 iterations in 4.632s)
# [t-SNE] Iteration 3200: error = 2.8874519, gradient norm = 0.0000155 (50 iterations in 4.589s)
# [t-SNE] Iteration 3250: error = 2.8872540, gradient norm = 0.0000142 (50 iterations in 4.532s)
# [t-SNE] Iteration 3300: error = 2.8870289, gradient norm = 0.0000160 (50 iterations in 4.383s)
# [t-SNE] Iteration 3350: error = 2.8868227, gradient norm = 0.0000174 (50 iterations in 4.913s)
# [t-SNE] Iteration 3400: error = 2.8866723, gradient norm = 0.0000152 (50 iterations in 4.848s)
# [t-SNE] Iteration 3450: error = 2.8864803, gradient norm = 0.0000162 (50 iterations in 5.174s)
# [t-SNE] Iteration 3500: error = 2.8863404, gradient norm = 0.0000160 (50 iterations in 4.676s)
# [t-SNE] Iteration 3550: error = 2.8861849, gradient norm = 0.0000153 (50 iterations in 4.897s)
# [t-SNE] Iteration 3600: error = 2.8860919, gradient norm = 0.0000161 (50 iterations in 4.427s)
# [t-SNE] Iteration 3650: error = 2.8860362, gradient norm = 0.0000153 (50 iterations in 3.852s)
# [t-SNE] Iteration 3700: error = 2.8859386, gradient norm = 0.0000133 (50 iterations in 4.091s)
# [t-SNE] Iteration 3750: error = 2.8857985, gradient norm = 0.0000124 (50 iterations in 4.100s)
# [t-SNE] Iteration 3800: error = 2.8856356, gradient norm = 0.0000135 (50 iterations in 4.027s)
# [t-SNE] Iteration 3850: error = 2.8854697, gradient norm = 0.0000122 (50 iterations in 3.744s)
# [t-SNE] Iteration 3900: error = 2.8853114, gradient norm = 0.0000116 (50 iterations in 4.094s)
# [t-SNE] Iteration 3950: error = 2.8851647, gradient norm = 0.0000118 (50 iterations in 4.013s)
# [t-SNE] Iteration 4000: error = 2.8849936, gradient norm = 0.0000117 (50 iterations in 3.756s)
# [t-SNE] Iteration 4050: error = 2.8847961, gradient norm = 0.0000123 (50 iterations in 4.135s)
# [t-SNE] Iteration 4100: error = 2.8846192, gradient norm = 0.0000133 (50 iterations in 3.958s)
# [t-SNE] Iteration 4150: error = 2.8844597, gradient norm = 0.0000125 (50 iterations in 3.834s)
# [t-SNE] Iteration 4200: error = 2.8843167, gradient norm = 0.0000122 (50 iterations in 3.937s)
# [t-SNE] Iteration 4250: error = 2.8841617, gradient norm = 0.0000122 (50 iterations in 3.877s)
# [t-SNE] Iteration 4300: error = 2.8840680, gradient norm = 0.0000123 (50 iterations in 3.688s)
# [t-SNE] Iteration 4350: error = 2.8839729, gradient norm = 0.0000112 (50 iterations in 3.877s)
# [t-SNE] Iteration 4400: error = 2.8838058, gradient norm = 0.0000107 (50 iterations in 3.898s)
# [t-SNE] Iteration 4450: error = 2.8836775, gradient norm = 0.0000112 (50 iterations in 3.733s)
# [t-SNE] Iteration 4500: error = 2.8835187, gradient norm = 0.0000122 (50 iterations in 3.921s)
# [t-SNE] Iteration 4550: error = 2.8834000, gradient norm = 0.0000120 (50 iterations in 3.877s)
# [t-SNE] Iteration 4600: error = 2.8832724, gradient norm = 0.0000115 (50 iterations in 3.770s)
# [t-SNE] Iteration 4650: error = 2.8831537, gradient norm = 0.0000113 (50 iterations in 3.898s)
# [t-SNE] Iteration 4700: error = 2.8830194, gradient norm = 0.0000107 (50 iterations in 3.948s)
# [t-SNE] Iteration 4750: error = 2.8828940, gradient norm = 0.0000113 (50 iterations in 3.882s)
# [t-SNE] Iteration 4800: error = 2.8827562, gradient norm = 0.0000107 (50 iterations in 3.937s)
# [t-SNE] Iteration 4850: error = 2.8826556, gradient norm = 0.0000119 (50 iterations in 5.360s)
# [t-SNE] Iteration 4900: error = 2.8825455, gradient norm = 0.0000116 (50 iterations in 4.071s)
# [t-SNE] Iteration 4950: error = 2.8824666, gradient norm = 0.0000122 (50 iterations in 3.828s)
# [t-SNE] Iteration 5000: error = 2.8823986, gradient norm = 0.0000099 (50 iterations in 3.933s)
# [t-SNE] Iteration 5050: error = 2.8822901, gradient norm = 0.0000105 (50 iterations in 3.954s)
# [t-SNE] Iteration 5100: error = 2.8822122, gradient norm = 0.0000099 (50 iterations in 3.759s)
# [t-SNE] Iteration 5150: error = 2.8821123, gradient norm = 0.0000113 (50 iterations in 3.893s)
# [t-SNE] Iteration 5200: error = 2.8820400, gradient norm = 0.0000107 (50 iterations in 3.913s)
# [t-SNE] Iteration 5250: error = 2.8819480, gradient norm = 0.0000100 (50 iterations in 3.849s)
# [t-SNE] Iteration 5300: error = 2.8818674, gradient norm = 0.0000112 (50 iterations in 3.872s)
# [t-SNE] Iteration 5350: error = 2.8817654, gradient norm = 0.0000099 (50 iterations in 3.960s)
# [t-SNE] Iteration 5400: error = 2.8816822, gradient norm = 0.0000097 (50 iterations in 3.917s)
# [t-SNE] Iteration 5450: error = 2.8815985, gradient norm = 0.0000093 (50 iterations in 4.065s)
# [t-SNE] Iteration 5500: error = 2.8815429, gradient norm = 0.0000096 (50 iterations in 3.993s)
# [t-SNE] Iteration 5550: error = 2.8814552, gradient norm = 0.0000099 (50 iterations in 3.950s)
# [t-SNE] Iteration 5600: error = 2.8813653, gradient norm = 0.0000106 (50 iterations in 4.148s)
# [t-SNE] Iteration 5650: error = 2.8812819, gradient norm = 0.0000098 (50 iterations in 3.990s)
# [t-SNE] Iteration 5700: error = 2.8812251, gradient norm = 0.0000094 (50 iterations in 3.984s)
# [t-SNE] Iteration 5750: error = 2.8811402, gradient norm = 0.0000107 (50 iterations in 3.691s)
# [t-SNE] Iteration 5800: error = 2.8810709, gradient norm = 0.0000104 (50 iterations in 3.904s)
# [t-SNE] Iteration 5850: error = 2.8809664, gradient norm = 0.0000100 (50 iterations in 4.090s)
# [t-SNE] Iteration 5900: error = 2.8809397, gradient norm = 0.0000091 (50 iterations in 3.820s)
# [t-SNE] Iteration 5950: error = 2.8808856, gradient norm = 0.0000115 (50 iterations in 3.989s)
# [t-SNE] Iteration 6000: error = 2.8808184, gradient norm = 0.0000097 (50 iterations in 3.948s)
# [t-SNE] Iteration 6050: error = 2.8807528, gradient norm = 0.0000092 (50 iterations in 3.866s)
# [t-SNE] Iteration 6100: error = 2.8806775, gradient norm = 0.0000099 (50 iterations in 4.056s)
# [t-SNE] Iteration 6150: error = 2.8806159, gradient norm = 0.0000093 (50 iterations in 4.049s)
# [t-SNE] Iteration 6200: error = 2.8805320, gradient norm = 0.0000090 (50 iterations in 4.172s)
# [t-SNE] Iteration 6250: error = 2.8804882, gradient norm = 0.0000102 (50 iterations in 4.222s)
# [t-SNE] Iteration 6300: error = 2.8804059, gradient norm = 0.0000103 (50 iterations in 3.854s)
# [t-SNE] Iteration 6350: error = 2.8803706, gradient norm = 0.0000090 (50 iterations in 3.965s)
# [t-SNE] Iteration 6400: error = 2.8803017, gradient norm = 0.0000096 (50 iterations in 3.782s)
# [t-SNE] Iteration 6450: error = 2.8802202, gradient norm = 0.0000101 (50 iterations in 4.088s)
# [t-SNE] Iteration 6500: error = 2.8801739, gradient norm = 0.0000096 (50 iterations in 4.604s)
# [t-SNE] Iteration 6550: error = 2.8801246, gradient norm = 0.0000088 (50 iterations in 4.014s)
# [t-SNE] Iteration 6600: error = 2.8800702, gradient norm = 0.0000091 (50 iterations in 6.389s)
# [t-SNE] Iteration 6650: error = 2.8799932, gradient norm = 0.0000091 (50 iterations in 5.282s)
# [t-SNE] Iteration 6700: error = 2.8799393, gradient norm = 0.0000084 (50 iterations in 4.842s)
# [t-SNE] Iteration 6750: error = 2.8798628, gradient norm = 0.0000086 (50 iterations in 4.977s)
# [t-SNE] Iteration 6800: error = 2.8798113, gradient norm = 0.0000084 (50 iterations in 5.116s)
# [t-SNE] Iteration 6850: error = 2.8797460, gradient norm = 0.0000095 (50 iterations in 7.279s)
# [t-SNE] Iteration 6900: error = 2.8796973, gradient norm = 0.0000089 (50 iterations in 5.434s)
# [t-SNE] Iteration 6950: error = 2.8796511, gradient norm = 0.0000078 (50 iterations in 4.828s)
# [t-SNE] Iteration 7000: error = 2.8795826, gradient norm = 0.0000083 (50 iterations in 4.216s)
# [t-SNE] Iteration 7050: error = 2.8795216, gradient norm = 0.0000083 (50 iterations in 4.341s)
# [t-SNE] Iteration 7100: error = 2.8794918, gradient norm = 0.0000084 (50 iterations in 5.189s)
# [t-SNE] Iteration 7150: error = 2.8794174, gradient norm = 0.0000095 (50 iterations in 4.954s)
# [t-SNE] Iteration 7200: error = 2.8793795, gradient norm = 0.0000093 (50 iterations in 6.127s)
# [t-SNE] Iteration 7250: error = 2.8793647, gradient norm = 0.0000095 (50 iterations in 6.523s)
# [t-SNE] Iteration 7300: error = 2.8793111, gradient norm = 0.0000091 (50 iterations in 4.628s)
# [t-SNE] Iteration 7350: error = 2.8792498, gradient norm = 0.0000097 (50 iterations in 4.384s)
# [t-SNE] Iteration 7400: error = 2.8792152, gradient norm = 0.0000094 (50 iterations in 4.197s)
# [t-SNE] Iteration 7450: error = 2.8791983, gradient norm = 0.0000087 (50 iterations in 4.282s)
# [t-SNE] Iteration 7500: error = 2.8791490, gradient norm = 0.0000089 (50 iterations in 4.166s)
# [t-SNE] Iteration 7550: error = 2.8791230, gradient norm = 0.0000096 (50 iterations in 4.250s)
# [t-SNE] Iteration 7600: error = 2.8790841, gradient norm = 0.0000086 (50 iterations in 4.115s)
# [t-SNE] Iteration 7650: error = 2.8790495, gradient norm = 0.0000079 (50 iterations in 4.041s)
# [t-SNE] Iteration 7700: error = 2.8790276, gradient norm = 0.0000080 (50 iterations in 4.048s)
# [t-SNE] Iteration 7750: error = 2.8789706, gradient norm = 0.0000082 (50 iterations in 4.371s)
# [t-SNE] Iteration 7800: error = 2.8789053, gradient norm = 0.0000094 (50 iterations in 3.657s)
# [t-SNE] Iteration 7850: error = 2.8788745, gradient norm = 0.0000086 (50 iterations in 3.688s)
# [t-SNE] Iteration 7900: error = 2.8788497, gradient norm = 0.0000075 (50 iterations in 4.059s)
# [t-SNE] Iteration 7950: error = 2.8788013, gradient norm = 0.0000075 (50 iterations in 3.772s)
# [t-SNE] Iteration 8000: error = 2.8787515, gradient norm = 0.0000079 (50 iterations in 3.259s)
# [t-SNE] Iteration 8050: error = 2.8787196, gradient norm = 0.0000082 (50 iterations in 3.624s)
# [t-SNE] Iteration 8100: error = 2.8787005, gradient norm = 0.0000088 (50 iterations in 3.943s)
# [t-SNE] Iteration 8150: error = 2.8786383, gradient norm = 0.0000077 (50 iterations in 4.381s)
# [t-SNE] Iteration 8200: error = 2.8785980, gradient norm = 0.0000078 (50 iterations in 4.123s)
# [t-SNE] Iteration 8250: error = 2.8785789, gradient norm = 0.0000077 (50 iterations in 4.076s)
# [t-SNE] Iteration 8300: error = 2.8785317, gradient norm = 0.0000084 (50 iterations in 3.900s)
# [t-SNE] Iteration 8350: error = 2.8784666, gradient norm = 0.0000078 (50 iterations in 4.309s)
# [t-SNE] Iteration 8400: error = 2.8784637, gradient norm = 0.0000075 (50 iterations in 4.170s)
# [t-SNE] Iteration 8450: error = 2.8784277, gradient norm = 0.0000104 (50 iterations in 3.727s)
# [t-SNE] Iteration 8500: error = 2.8784058, gradient norm = 0.0000088 (50 iterations in 4.071s)
# [t-SNE] Iteration 8550: error = 2.8783786, gradient norm = 0.0000092 (50 iterations in 4.312s)
# [t-SNE] Iteration 8600: error = 2.8783278, gradient norm = 0.0000087 (50 iterations in 4.145s)
# [t-SNE] Iteration 8650: error = 2.8782771, gradient norm = 0.0000075 (50 iterations in 4.127s)
# [t-SNE] Iteration 8700: error = 2.8782613, gradient norm = 0.0000080 (50 iterations in 4.207s)
# [t-SNE] Iteration 8750: error = 2.8782325, gradient norm = 0.0000074 (50 iterations in 4.395s)
# [t-SNE] Iteration 8800: error = 2.8782070, gradient norm = 0.0000067 (50 iterations in 4.007s)
# [t-SNE] Iteration 8850: error = 2.8781738, gradient norm = 0.0000081 (50 iterations in 4.152s)
# [t-SNE] Iteration 8900: error = 2.8781559, gradient norm = 0.0000084 (50 iterations in 4.424s)
# [t-SNE] Iteration 8950: error = 2.8781271, gradient norm = 0.0000073 (50 iterations in 4.207s)
# [t-SNE] Iteration 9000: error = 2.8780882, gradient norm = 0.0000077 (50 iterations in 4.204s)
# [t-SNE] Iteration 9050: error = 2.8780608, gradient norm = 0.0000069 (50 iterations in 4.084s)
# [t-SNE] Iteration 9100: error = 2.8780332, gradient norm = 0.0000075 (50 iterations in 4.138s)
# [t-SNE] Iteration 9150: error = 2.8779857, gradient norm = 0.0000081 (50 iterations in 4.015s)
# [t-SNE] Iteration 9200: error = 2.8779495, gradient norm = 0.0000090 (50 iterations in 3.699s)
# [t-SNE] Iteration 9250: error = 2.8779089, gradient norm = 0.0000075 (50 iterations in 3.780s)
# [t-SNE] Iteration 9300: error = 2.8778675, gradient norm = 0.0000084 (50 iterations in 3.764s)
# [t-SNE] Iteration 9350: error = 2.8778472, gradient norm = 0.0000078 (50 iterations in 3.837s)
# [t-SNE] Iteration 9400: error = 2.8778276, gradient norm = 0.0000070 (50 iterations in 3.892s)
# [t-SNE] Iteration 9450: error = 2.8778050, gradient norm = 0.0000067 (50 iterations in 3.902s)
# [t-SNE] Iteration 9500: error = 2.8777699, gradient norm = 0.0000068 (50 iterations in 3.851s)
# [t-SNE] Iteration 9550: error = 2.8777428, gradient norm = 0.0000080 (50 iterations in 3.910s)
# [t-SNE] Iteration 9600: error = 2.8777187, gradient norm = 0.0000068 (50 iterations in 3.899s)
# [t-SNE] Iteration 9650: error = 2.8776989, gradient norm = 0.0000094 (50 iterations in 3.877s)
# [t-SNE] Iteration 9700: error = 2.8776884, gradient norm = 0.0000078 (50 iterations in 4.067s)
# [t-SNE] Iteration 9750: error = 2.8776562, gradient norm = 0.0000068 (50 iterations in 3.910s)
# [t-SNE] Iteration 9800: error = 2.8776305, gradient norm = 0.0000077 (50 iterations in 3.993s)
# [t-SNE] Iteration 9850: error = 2.8776183, gradient norm = 0.0000069 (50 iterations in 3.848s)
# [t-SNE] Iteration 9900: error = 2.8775959, gradient norm = 0.0000071 (50 iterations in 3.933s)
# [t-SNE] Iteration 9950: error = 2.8775699, gradient norm = 0.0000065 (50 iterations in 3.845s)
# [t-SNE] Iteration 10000: error = 2.8775580, gradient norm = 0.0000086 (50 iterations in 4.046s)
# [t-SNE] KL divergence after 10000 iterations: 2.877558
# --- 852.7692537307739 seconds ---

# %%
df=pd.DataFrame(all_word_vectors_matrix_2d,columns=['X','Y'])

df.head(10)

train.head()

df.reset_index(drop=True, inplace=True)
train.reset_index(drop=True, inplace=True)

# %% [markdown]
# Joining two dataframes to obtain each song's corresponding X,Y co-ordinate.

# %%
two_dimensional_songs = pd.concat([train, df], axis=1)

two_dimensional_songs.head()
# Out:
#    id                artista                              cancion  \
# 0   1  Ceerre y Pablo Gareta                             Concepto
# 1  17                Hard GZ                              Monster
# 2  23                  Dante                                Calma
# 3  54                   SFDK                           Lo intento
# 4  28                   SFDK  Seguimos fuertes (con Jefe de la M)
#
#                            album  \
# 0                    Grey theory
# 1                     Nictofilia
# 2  Sin álbum, es un vídeo suelto
# 3              Tesoros y caras B
# 4              Siempre fuertes 2
#
#                                                letra  anyo  visitas  \
# 0  [Ceerre]\nCon esta presión dentro desde pequeñ...  2015     1229
# 1  Cada día me acuerdo de cuando tenía 6 años,\nf...  2015     6032
# 2  Ahora voy a hablar, pa' dejar las cosas claras...  2017     8173
# 3  Tú di, tú di, jefe de la M, ?ok?,\nespecial de...  2010     1037
# 4  [Estribillo]\nSuenan Jefe y SFDK\nsi no siente...  2009     3408
#
#                                          song_vector          X          Y
# 0  [[-0.034195747, 0.09055399, 0.1346869, -0.1285...   9.781878 -61.608582
# 1  [[-0.033740018, 0.10971237, 0.14973374, -0.174...  40.164669 -14.228997
# 2  [[-0.05179523, 0.103807546, 0.16787839, -0.209... -25.296196  65.582489
# 3  [[-0.025074981, 0.09681175, 0.1696142, -0.1441... -15.371625  -3.844587
# 4  [[-0.04357646, 0.09102699, 0.1567576, -0.14719...   1.411984 -57.916382

# %% [markdown]
# **Plotting the results**
#
# Using plotly, I plotted the results so that it becomes easier to explore similar songs based on their colors and clusters.

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

import plotly.graph_objs as go

trace1 = go.Scatter(
    y = two_dimensional_songs['Y'],
    x = two_dimensional_songs['X'],
    text = two_dimensional_songs['artista'],
    mode='markers',
    marker=dict(
        size= 5,#'7',
        color = two_dimensional_songs['artista'].astype('category').cat.codes, #set color equal to a variable
        colorscale='Viridis',
        showscale=True
    )
)
data = [trace1]

iplot(data)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="ae37774c-f918-49cd-ab02-1ea19ae9c1e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ae37774c-f918-49cd-ab02-1ea19ae9c1e6")) {
#                     Plotly.newPlot(
#                         'ae37774c-f918-49cd-ab02-1ea19ae9c1e6',
#                         [{"marker": {"color": [187, 566, 275, 1148, 1148, 984, 539, 904, 616, 1123, 545, 1387, 1089, 1363, 441, 140, 478, 313, 939, 764, 912, 177, 887, 1185, 735, 575, 1041, 892, 1122, 1004, 851, 967, 807, 707, 510, 1172, 982, 936, 840, 66, 551, 514, 959, 814, 156, 665, 1139, 405, 495, 1076, 1144, 707, 1303, 459, 848, 19, 939, 939, 1211, 1211, 1345, 742, 800, 121, 823, 278, 782, 1359, 925, 441, 1221, 42, 211, 1017, 586, 1353, 172, 1099, 1119, 474, 1017, 1148, 3, 1041, 1076, 910, 1043, 1076, 1009, 823, 1216, 231, 394, 616, 290, 1216, 222, 1345, 259, 829, 1312, 951, 829, 855, 417, 539, 104, 267, 379, 760, 961, 1109, 1326, 1286, 501, 985, 1028, 1270, 830, 239, 1, 539, 1009, 59, 451, 394, 983, 529, 46, 1073, 877, 949, 1409, 1078, 72, 360, 50, 345, 630, 1078, 830, 710, 915, 211, 1395, 127, 239, 670, 1045, 474, 808, 645, 726, 1041, 83, 337, 943, 390, 381, 997, 1046, 1110, 1204, 376, 267, 156, 485, 768, 1349, 679, 222, 1307, 460, 1110, 1270, 1387, 844, 691, 1041, 1103, 355, 83, 1179, 679, 1221, 183, 118, 246, 969, 750, 266, 866, 816, 421, 1242, 203, 408, 545, 1063, 432, 1116, 1041, 1089, 745, 1276, 1148, 735, 1021, 665, 1089, 267, 240, 448, 268, 1115, 184, 473, 361, 1251, 1115, 1206, 46, 118, 1099, 172, 1216, 611, 1046, 828, 659, 185, 102, 600, 474, 90, 764, 1304, 965, 426, 45, 1067, 214, 24, 1214, 275, 1209, 392, 338, 237, 1307, 1073, 361, 1139, 900, 1148, 1021, 485, 476, 59, 59, 279, 144, 738, 652, 1089, 196, 1278, 450, 920, 200, 612, 1129, 1321, 818, 710, 936, 474, 169, 1089, 1387, 394, 563, 1116, 1038, 1332, 851, 1162, 559, 1406, 1273, 55, 1231, 311, 1332, 544, 961, 1406, 59, 1221, 1167, 883, 1062, 315, 1073, 510, 1062, 140, 999, 961, 677, 331, 1376, 311, 1118, 1406, 1043, 642, 5, 525, 912, 1221, 70, 808, 210, 140, 925, 864, 1360, 544, 0, 1214, 97, 264, 979, 1205, 311, 191, 1337, 1336, 916, 656, 580, 614, 100, 1313, 311, 154, 200, 1166, 679, 1304, 590, 1170, 140, 707, 647, 394, 409, 166, 393, 1321, 722, 911, 1133, 765, 1304, 237, 1211, 855, 785, 997, 850, 66, 203, 679, 1065, 1234, 612, 241, 807, 851, 155, 239, 960, 1363, 1021, 1040, 679, 394, 1225, 566, 1041, 81, 158, 1387, 1148, 1148, 72, 8, 1357, 772, 916, 1337, 17, 1345, 254, 707, 83, 1021, 518, 551, 518, 668, 1068, 66, 1263, 854, 172, 970, 172, 376, 59, 172, 830, 594, 1148, 401, 1276, 363, 464, 981, 1033, 1151, 1041, 1104, 1304, 710, 129, 271, 62, 362, 1273, 54, 1063, 1172, 292, 1409, 814, 1286, 988, 679, 937, 1048, 679, 925, 925, 1321, 1406, 665, 1008, 871, 969, 1211, 807, 961, 669, 873, 85, 200, 925, 459, 1043, 1341, 1368, 925, 1172, 489, 739, 267, 925, 200, 1246, 1105, 852, 318, 925, 72, 861, 679, 1256, 392, 925, 1103, 817, 377, 263, 1033, 676, 459, 100, 739, 586, 1304, 1151, 881, 263, 1387, 1099, 798, 1172, 1253, 675, 1317, 74, 1117, 1301, 194, 569, 823, 1069, 1411, 1387, 1268, 531, 1278, 809, 339, 1363, 352, 704, 1404, 1041, 561, 601, 556, 961, 975, 647, 1009, 1363, 1055, 762, 85, 159, 1276, 807, 1166, 527, 1421, 755, 1099, 1205, 1304, 100, 267, 1363, 505, 1332, 246, 823, 611, 1041, 1303, 1345, 357, 404, 1062, 596, 1081, 394, 42, 929, 1345, 1148, 629, 208, 707, 1424, 1251, 494, 807, 503, 1369, 173, 180, 1204, 267, 447, 474, 183, 914, 1089, 563, 855, 338, 735, 847, 261, 1072, 1089, 598, 505, 1305, 199, 679, 1298, 932, 267, 447, 1021, 1313, 1317, 906, 1092, 1304, 146, 362, 313, 638, 59, 1148, 653, 1041, 1216, 198, 65, 87, 404, 1021, 1093, 83, 1003, 679, 961, 369, 1038, 718, 503, 1021, 811, 707, 1342, 872, 381, 843, 72, 823, 819, 793, 1148, 612, 925, 81, 50, 1342, 131, 762, 4, 237, 140, 582, 1078, 794, 357, 1265, 1221, 24, 355, 707, 485, 1304, 1363, 200, 65, 1033, 177, 866, 639, 1255, 1363, 301, 271, 1307, 107, 72, 1009, 155, 100, 381, 918, 1166, 939, 1387, 59, 1144, 997, 1089, 24, 1148, 183, 338, 1041, 200, 807, 1166, 474, 554, 1331, 135, 830, 823, 594, 840, 1221, 616, 1295, 140, 823, 725, 1345, 1008, 680, 596, 674, 1359, 44, 925, 1340, 103, 1276, 881, 1371, 558, 807, 166, 938, 466, 1046, 1021, 203, 1352, 1148, 311, 126, 1148, 459, 173, 762, 1148, 925, 98,  ...

# %% [markdown]
# ### Como hay demasiados artistas, plotly reutiliza clores y es imposible saber si se está clusterizando bien, por lo que reduciremos el dataset a 5 cantantes

# %%
artists = ["SFDK", "Rayden", "Dendro", "Nach", "Dante"]
parcial_artists = two_dimensional_songs[two_dimensional_songs['artista'].isin(artists)]

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

import plotly.graph_objs as go

trace1 = go.Scatter(
    y = parcial_artists['Y'],
    x = parcial_artists['X'],
    text = parcial_artists['artista'],
    mode='markers',
    marker=dict(
        size= 5,#'7',
        color = parcial_artists['artista'].astype('category').cat.codes, #set color equal to a variable
        colorscale='Viridis',
        showscale=True
    )
)
data = [trace1]

iplot(data)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="ca815292-f4c5-453f-9a81-82d2c5f061c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca815292-f4c5-453f-9a81-82d2c5f061c2")) {
#                     Plotly.newPlot(
#                         'ca815292-f4c5-453f-9a81-82d2c5f061c2',
#                         [{"marker": {"color": [0, 4, 4, 3, 2, 4, 3, 4, 3, 0, 4, 3, 3, 2, 4, 4, 4, 2, 2, 2, 2, 2, 2, 2, 4, 3, 3, 4, 4, 2, 3, 4, 2, 4, 4, 4, 2, 4, 2, 3, 4, 2, 2, 4, 3, 4, 4, 3, 3, 2, 4, 3, 2, 2, 4, 2, 2, 4, 2, 3, 2, 2, 4, 4, 2, 4, 3, 2, 2, 4, 2, 4, 2, 0, 3, 4, 4, 3, 0, 2, 2, 4, 4, 2, 2, 2, 4, 2, 2, 2, 3, 3, 3, 4, 2, 2, 4, 2, 3, 2, 0, 4, 4, 2, 3, 2, 4, 2, 0, 2, 4, 2, 2, 3, 4, 2, 2, 4, 3, 3, 4, 4, 2, 4, 3, 4, 2, 2, 1, 3, 3, 4, 3, 4, 2, 3, 3, 0, 4, 4, 2, 2, 4, 2, 2, 4, 2, 4, 3, 4, 3, 4, 0, 2, 4, 4, 2, 3, 3, 3, 0, 3, 3, 4, 2, 2, 2, 4, 3, 4, 4, 2, 4, 4, 2, 4, 2, 3, 3, 4, 3, 4, 2, 3, 4, 2, 3, 2, 4, 4, 2, 4, 3, 4, 2, 2, 2, 4, 4, 4, 2, 2, 2, 4, 2, 2, 4, 4, 2, 4, 3, 4, 3, 2, 4, 2, 4, 3, 4, 2, 2, 4, 2, 3, 2, 4, 2, 4, 4, 3, 4, 2, 0, 2, 4, 3, 4, 4, 3, 4, 3, 2, 2, 2, 2, 4, 4, 0, 2, 2, 2, 2, 2, 3, 2, 2, 3, 2, 3, 3, 0, 4, 3, 4, 3, 2, 4, 4, 3, 4, 3, 4, 4, 3, 3, 2, 4, 4, 2, 4, 2, 2, 3, 4, 4, 4, 4], "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "showscale": true, "size": 5}, "mode": "markers", "text": ["Dante", "SFDK", "SFDK", "Rayden", "Nach", "SFDK", "Rayden", "SFDK", "Rayden", "Dante", "SFDK", "Rayden", "Rayden", "Nach", "SFDK", "SFDK", "SFDK", "Nach", "Nach", "Nach", "Nach", "Nach", "Nach", "Nach", "SFDK", "Rayden", "Rayden", "SFDK", "SFDK", "Nach", "Rayden", "SFDK", "Nach", "SFDK", "SFDK", "SFDK", "Nach", "SFDK", "Nach", "Rayden", "SFDK", "Nach", "Nach", "SFDK", "Rayden", "SFDK", "SFDK", "Rayden", "Rayden", "Nach", "SFDK", "Rayden", "Nach", "Nach", "SFDK", "Nach", "Nach", "SFDK", "Nach", "Rayden", "Nach", "Nach", "SFDK", "SFDK", "Nach", "SFDK", "Rayden", "Nach", "Nach", "SFDK", "Nach", "SFDK", "Nach", "Dante", "Rayden", "SFDK", "SFDK", "Rayden", "Dante", "Nach", "Nach", "SFDK", "SFDK", "Nach", "Nach", "Nach", "SFDK", "Nach", "Nach", "Nach", "Rayden", "Rayden", "Rayden", "SFDK", "Nach", "Nach", "SFDK", "Nach", "Rayden", "Nach", "Dante", "SFDK", "SFDK", "Nach", "Rayden", "Nach", "SFDK", "Nach", "Dante", "Nach", "SFDK", "Nach", "Nach", "Rayden", "SFDK", "Nach", "Nach", "SFDK", "Rayden", "Rayden", "SFDK", "SFDK", "Nach", "SFDK", "Rayden", "SFDK", "Nach", "Nach", "Dendro", "Rayden", "Rayden", "SFDK", "Rayden", "SFDK", "Nach", "Rayden", "Rayden", "Dante", "SFDK", "SFDK", "Nach", "Nach", "SFDK", "Nach", "Nach", "SFDK", "Nach", "SFDK", "Rayden", "SFDK", "Rayden", "SFDK", "Dante", "Nach", "SFDK", "SFDK", "Nach", "Rayden", "Rayden", "Rayden", "Dante", "Rayden", "Rayden", "SFDK", "Nach", "Nach", "Nach", "SFDK", "Rayden", "SFDK", "SFDK", "Nach", "SFDK", "SFDK", "Nach", "SFDK", "Nach", "Rayden", "Rayden", "SFDK", "Rayden", "SFDK", "Nach", "Rayden", "SFDK", "Nach", "Rayden", "Nach", "SFDK", "SFDK", "Nach", "SFDK", "Rayden", "SFDK", "Nach", "Nach", "Nach", "SFDK", "SFDK", "SFDK", "Nach", "Nach", "Nach", "SFDK", "Nach", "Nach", "SFDK", "SFDK", "Nach", "SFDK", "Rayden", "SFDK", "Rayden", "Nach", "SFDK", "Nach", "SFDK", "Rayden", "SFDK", "Nach", "Nach", "SFDK", "Nach", "Rayden", "Nach", "SFDK", "Nach", "SFDK", "SFDK", "Rayden", "SFDK", "Nach", "Dante", "Nach", "SFDK", "Rayden", "SFDK", "SFDK", "Rayden", "SFDK", "Rayden", "Nach", "Nach", "Nach", "Nach", "SFDK", "SFDK", "Dante", "Nach", "Nach", "Nach", "Nach", "Nach", "Rayden", "Nach", "Nach", "Rayden", "Nach", "Rayden", "Rayden", "Dante", "SFDK", "Rayden", "SFDK", "Rayden", "Nach", "SFDK", "SFDK", "Rayden", "SFDK", "Rayden", "SFDK", "SFDK", "Rayden", "Rayden", "Nach", "SFDK", "SFDK", "Nach", "SFDK", "Nach", "Nach", "Rayden", "SFDK", "SFDK", "SFDK", "SFDK"], "type": "scatter", "x": [-25.29619598388672, -15.371624946594238, 1.4119843244552612, 7.840165615081787, -36.409095764160156, 22.3043155670166, -39.6111946105957, 39.08672332763672, -28.63494873046875, -34.076900482177734, 50.785301208496094, -77.17881774902344, -14.6051816940 ...

# %% [markdown]
# #### Cómo se muestra en la imagen, no somos capaces de separar claramente a los 5 artistas, pero si que se ve claramente que cada uno tiene un estilo completamente distinto y se observa que las canciones de Rayden y Nach son más variopintas que las de Dante o las de SFDK.

# %% [markdown]
# ## Canciones 3D

# %% [markdown]
# ### En el caso del plot en tres dimensionse se ha representado directamente a los 5 artistas anteriores,

# %%
song_vectors = []
from sklearn.model_selection import train_test_split

artists = ["SFDK", "Rayden", "Dendro", "Nach", "Dante"]
parcial_artists = songs[songs['artista'].isin(artists)]

train, test = train_test_split(parcial_artists, test_size = 0.2)


for song_vector in train['song_vector']:
    song_vectors.append(song_vector)

train.head(10)
# Out:
#       id artista                                            cancion  \
# 139   29    Nach                       Cuando ya no esté (con Klau)
# 2667  27    SFDK                               El perro anda suelto
# 7241   6  Rayden                          El violinista del titanic
# 6017  47  Rayden                          Imperdible (con Sidecars)
# 2613  28    Nach                                         Manifiesto
# 7244   9  Rayden                                       Controversia
# 7017   2    SFDK  Digan lo que quieran (con Little Pepe, Jefe de...
# 947   12    Nach                     Los años luz (con Diana Feria)
# 3641  11    Nach                                   Repaso mis pasos
# 7797  12    Nach                                  El Hip Hop que sé
#
#                     album                                              letra  \
# 139             Almanauta  [Nach]\n¿Cuánto tiempo me queda? Los años vuel...
# 2667  Desde los chiqueros  Hoy ya somos la pareja con compatibilidad, y v...
# 7241      En alma y hueso  Tras el duro invier(_) siempre sale el sol de ...
# 6017             Antónimo  Podré perder el norte,\nPodré perderme en dond...
# 2613   Un día en suburbia  Mi padre es el sol, mi madre la luna\nmi herma...
# 7244      En alma y hueso  Embajadores del rap, puristas anclados atrás,\...
# 7017   Lista de invitados  [Estribillo: Little Pepe] (x2)\nDeja que hable...
# 947    Un día en suburbia  [Nach]\nYeah, un día en suburbia, esto esta de...
# 3641  Ars Magna / Miradas  Todo empezó de manera sencilla,\nquería tener ...
# 7797       A través de mí  El Hip Hop que sé no calla, habla fuerte y alt...
#
#       anyo  visitas                                        song_vector
# 139   2018     3823  [[-0.045673825, 0.11685847, 0.18566772, -0.196...
# 2667  2000     3841  [[-0.039533764, 0.07019628, 0.14477897, -0.155...
# 7241  2014     2447  [[-0.033285853, 0.13485606, 0.1683339, -0.1798...
# 6017  2017    21931  [[-0.030984491, 0.14549348, 0.19831865, -0.185...
# 2613  2008    21397  [[-0.053237442, 0.097117715, 0.16198772, -0.17...
# 7244  2014     4153  [[-0.045818407, 0.099605605, 0.17925186, -0.18...
# 7017  2011     1251  [[-0.039689604, 0.060751934, 0.18773203, -0.19...
# 947   2008     5147  [[-0.035146303, 0.10290157, 0.1688699, -0.2011...
# 3641  2005     4724  [[-0.010917659, 0.13445596, 0.15909608, -0.144...
# 7797  2015     6738  [[-0.041176964, 0.13488114, 0.14056477, -0.167...

# %%
X = np.array(song_vectors).reshape((int(len(song_vectors)*num_features/num_features), num_features))

start_time = time.time()
tsne = sklearn.manifold.TSNE(n_components=3, n_iter=10000, random_state=0, verbose=10)

all_word_vectors_matrix_3d = tsne.fit_transform(X)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 292 samples in 0.006s...
# [t-SNE] Computed neighbors for 292 samples in 0.028s...
# [t-SNE] Computed conditional probabilities for sample 292 / 292
# [t-SNE] Mean sigma: 0.081829
# [t-SNE] Computed conditional probabilities in 0.017s
# [t-SNE] Iteration 50: error = 108.0790558, gradient norm = 0.1826579 (50 iterations in 0.265s)
# [t-SNE] Iteration 100: error = 129.8995514, gradient norm = 0.1182012 (50 iterations in 0.489s)
# [t-SNE] Iteration 150: error = 139.3829651, gradient norm = 0.1434451 (50 iterations in 0.221s)
# [t-SNE] Iteration 200: error = 148.7807617, gradient norm = 0.0894067 (50 iterations in 0.163s)
# [t-SNE] Iteration 250: error = 150.9445496, gradient norm = 0.0879795 (50 iterations in 0.216s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 150.944550
# [t-SNE] Iteration 300: error = 4.3100562, gradient norm = 0.0004980 (50 iterations in 0.167s)
# [t-SNE] Iteration 350: error = 3.6914742, gradient norm = 0.0002020 (50 iterations in 0.170s)
# [t-SNE] Iteration 400: error = 3.3742533, gradient norm = 0.0001174 (50 iterations in 0.158s)
# [t-SNE] Iteration 450: error = 3.1733248, gradient norm = 0.0000813 (50 iterations in 0.164s)
# [t-SNE] Iteration 500: error = 3.0262198, gradient norm = 0.0000601 (50 iterations in 0.162s)
# [t-SNE] Iteration 550: error = 2.9148982, gradient norm = 0.0000478 (50 iterations in 0.173s)
# [t-SNE] Iteration 600: error = 2.8185735, gradient norm = 0.0000401 (50 iterations in 0.179s)
# [t-SNE] Iteration 650: error = 2.7384572, gradient norm = 0.0000322 (50 iterations in 0.213s)
# [t-SNE] Iteration 700: error = 2.6737347, gradient norm = 0.0000279 (50 iterations in 0.169s)
# [t-SNE] Iteration 750: error = 2.6137896, gradient norm = 0.0000243 (50 iterations in 0.172s)
# [t-SNE] Iteration 800: error = 2.5602024, gradient norm = 0.0000217 (50 iterations in 0.157s)
# [t-SNE] Iteration 850: error = 2.5141237, gradient norm = 0.0000188 (50 iterations in 0.171s)
# [t-SNE] Iteration 900: error = 2.4747629, gradient norm = 0.0000171 (50 iterations in 0.143s)
# [t-SNE] Iteration 950: error = 2.4389067, gradient norm = 0.0000158 (50 iterations in 0.183s)
# [t-SNE] Iteration 1000: error = 2.4054208, gradient norm = 0.0000147 (50 iterations in 0.146s)
# [t-SNE] Iteration 1050: error = 2.3736842, gradient norm = 0.0000135 (50 iterations in 0.177s)
# [t-SNE] Iteration 1100: error = 2.3443134, gradient norm = 0.0000128 (50 iterations in 0.198s)
# [t-SNE] Iteration 1150: error = 2.3158185, gradient norm = 0.0000120 (50 iterations in 0.249s)
# [t-SNE] Iteration 1200: error = 2.2905638, gradient norm = 0.0000114 (50 iterations in 0.208s)
# [t-SNE] Iteration 1250: error = 2.2649677, gradient norm = 0.0000115 (50 iterations in 0.219s)
# [t-SNE] Iteration 1300: error = 2.2392485, gradient norm = 0.0000102 (50 iterations in 0.208s)
# [t-SNE] Iteration 1350: error = 2.2140870, gradient norm = 0.0000096 (50 iterations in 0.216s)
# [t-SNE] Iteration 1400: error = 2.1909695, gradient norm = 0.0000086 (50 iterations in 0.220s)
# [t-SNE] Iteration 1450: error = 2.1712205, gradient norm = 0.0000080 (50 iterations in 0.201s)
# [t-SNE] Iteration 1500: error = 2.1537855, gradient norm = 0.0000075 (50 iterations in 0.370s)
# [t-SNE] Iteration 1550: error = 2.1373425, gradient norm = 0.0000071 (50 iterations in 0.317s)
# [t-SNE] Iteration 1600: error = 2.1218114, gradient norm = 0.0000068 (50 iterations in 0.199s)
# [t-SNE] Iteration 1650: error = 2.1059427, gradient norm = 0.0000066 (50 iterations in 0.231s)
# [t-SNE] Iteration 1700: error = 2.0902159, gradient norm = 0.0000063 (50 iterations in 0.209s)
# [t-SNE] Iteration 1750: error = 2.0741680, gradient norm = 0.0000061 (50 iterations in 0.232s)
# [t-SNE] Iteration 1800: error = 2.0581086, gradient norm = 0.0000058 (50 iterations in 0.221s)
# [t-SNE] Iteration 1850: error = 2.0433373, gradient norm = 0.0000056 (50 iterations in 0.244s)
# [t-SNE] Iteration 1900: error = 2.0289636, gradient norm = 0.0000053 (50 iterations in 0.223s)
# [t-SNE] Iteration 1950: error = 2.0150032, gradient norm = 0.0000051 (50 iterations in 0.231s)
# [t-SNE] Iteration 2000: error = 2.0016494, gradient norm = 0.0000049 (50 iterations in 0.154s)
# [t-SNE] Iteration 2050: error = 1.9885371, gradient norm = 0.0000047 (50 iterations in 0.171s)
# [t-SNE] Iteration 2100: error = 1.9757142, gradient norm = 0.0000046 (50 iterations in 0.193s)
# [t-SNE] Iteration 2150: error = 1.9630799, gradient norm = 0.0000044 (50 iterations in 0.232s)
# [t-SNE] Iteration 2200: error = 1.9499755, gradient norm = 0.0000043 (50 iterations in 0.187s)
# [t-SNE] Iteration 2250: error = 1.9370162, gradient norm = 0.0000043 (50 iterations in 0.182s)
# [t-SNE] Iteration 2300: error = 1.9228040, gradient norm = 0.0000042 (50 iterations in 0.211s)
# [t-SNE] Iteration 2350: error = 1.9087253, gradient norm = 0.0000042 (50 iterations in 0.217s)
# [t-SNE] Iteration 2400: error = 1.8942056, gradient norm = 0.0000042 (50 iterations in 0.224s)
# [t-SNE] Iteration 2450: error = 1.8785460, gradient norm = 0.0000041 (50 iterations in 0.180s)
# [t-SNE] Iteration 2500: error = 1.8633351, gradient norm = 0.0000040 (50 iterations in 0.173s)
# [t-SNE] Iteration 2550: error = 1.8489411, gradient norm = 0.0000039 (50 iterations in 0.206s)
# [t-SNE] Iteration 2600: error = 1.8359812, gradient norm = 0.0000037 (50 iterations in 0.178s)
# [t-SNE] Iteration 2650: error = 1.8235282, gradient norm = 0.0000037 (50 iterations in 0.153s)
# [t-SNE] Iteration 2700: error = 1.8108391, gradient norm = 0.0000035 (50 iterations in 0.172s)
# [t-SNE] Iteration 2750: error = 1.7984909, gradient norm = 0.0000034 (50 iterations in 0.184s)
# [t-SNE] Iteration 2800: error = 1.7870606, gradient norm = 0.0000032 (50 iterations in 0.226s)
# [t-SNE] Iteration 2850: error = 1.7769291, gradient norm = 0.0000031 (50 iterations in 0.299s)
# [t-SNE] Iteration 2900: error = 1.7672139, gradient norm = 0.0000030 (50 iterations in 0.266s)
# [t-SNE] Iteration 2950: error = 1.7576414, gradient norm = 0.0000029 (50 iterations in 0.180s)
# [t-SNE] Iteration 3000: error = 1.7475265, gradient norm = 0.0000029 (50 iterations in 0.188s)
# [t-SNE] Iteration 3050: error = 1.7376436, gradient norm = 0.0000029 (50 iterations in 0.187s)
# [t-SNE] Iteration 3100: error = 1.7289116, gradient norm = 0.0000029 (50 iterations in 0.224s)
# [t-SNE] Iteration 3150: error = 1.7197018, gradient norm = 0.0000029 (50 iterations in 0.185s)
# [t-SNE] Iteration 3200: error = 1.7089853, gradient norm = 0.0000028 (50 iterations in 0.147s)
# [t-SNE] Iteration 3250: error = 1.7013209, gradient norm = 0.0000027 (50 iterations in 0.139s)
# [t-SNE] Iteration 3300: error = 1.6952155, gradient norm = 0.0000026 (50 iterations in 0.146s)
# [t-SNE] Iteration 3350: error = 1.6888568, gradient norm = 0.0000026 (50 iterations in 0.141s)
# [t-SNE] Iteration 3400: error = 1.6809316, gradient norm = 0.0000027 (50 iterations in 0.142s)
# [t-SNE] Iteration 3450: error = 1.6727476, gradient norm = 0.0000028 (50 iterations in 0.148s)
# [t-SNE] Iteration 3500: error = 1.6671836, gradient norm = 0.0000027 (50 iterations in 0.135s)
# [t-SNE] Iteration 3550: error = 1.6623150, gradient norm = 0.0000023 (50 iterations in 0.212s)
# [t-SNE] Iteration 3600: error = 1.6587336, gradient norm = 0.0000022 (50 iterations in 0.221s)
# [t-SNE] Iteration 3650: error = 1.6555066, gradient norm = 0.0000021 (50 iterations in 0.224s)
# [t-SNE] Iteration 3700: error = 1.6519574, gradient norm = 0.0000020 (50 iterations in 0.182s)
# [t-SNE] Iteration 3750: error = 1.6489536, gradient norm = 0.0000019 (50 iterations in 0.155s)
# [t-SNE] Iteration 3800: error = 1.6462127, gradient norm = 0.0000019 (50 iterations in 0.186s)
# [t-SNE] Iteration 3850: error = 1.6433469, gradient norm = 0.0000018 (50 iterations in 0.202s)
# [t-SNE] Iteration 3900: error = 1.6408753, gradient norm = 0.0000017 (50 iterations in 0.164s)
# [t-SNE] Iteration 3950: error = 1.6381267, gradient norm = 0.0000017 (50 iterations in 0.190s)
# [t-SNE] Iteration 4000: error = 1.6354454, gradient norm = 0.0000016 (50 iterations in 0.169s)
# [t-SNE] Iteration 4050: error = 1.6331106, gradient norm = 0.0000016 (50 iterations in 0.194s)
# [t-SNE] Iteration 4100: error = 1.6306679, gradient norm = 0.0000015 (50 iterations in 0.198s)
# [t-SNE] Iteration 4150: error = 1.6282645, gradient norm = 0.0000015 (50 iterations in 0.193s)
# [t-SNE] Iteration 4200: error = 1.6260575, gradient norm = 0.0000015 (50 iterations in 0.214s)
# [t-SNE] Iteration 4250: error = 1.6239326, gradient norm = 0.0000014 (50 iterations in 0.191s)
# [t-SNE] Iteration 4300: error = 1.6218773, gradient norm = 0.0000014 (50 iterations in 0.388s)
# [t-SNE] Iteration 4350: error = 1.6197468, gradient norm = 0.0000014 (50 iterations in 0.402s)
# [t-SNE] Iteration 4400: error = 1.6177889, gradient norm = 0.0000014 (50 iterations in 0.275s)
# [t-SNE] Iteration 4450: error = 1.6155798, gradient norm = 0.0000013 (50 iterations in 0.211s)
# [t-SNE] Iteration 4500: error = 1.6135080, gradient norm = 0.0000013 (50 iterations in 0.210s)
# [t-SNE] Iteration 4550: error = 1.6114439, gradient norm = 0.0000013 (50 iterations in 0.201s)
# [t-SNE] Iteration 4600: error = 1.6093907, gradient norm = 0.0000013 (50 iterations in 0.195s)
# [t-SNE] Iteration 4650: error = 1.6071615, gradient norm = 0.0000013 (50 iterations in 0.157s)
# [t-SNE] Iteration 4700: error = 1.6053094, gradient norm = 0.0000012 (50 iterations in 0.187s)
# [t-SNE] Iteration 4750: error = 1.6035779, gradient norm = 0.0000012 (50 iterations in 0.190s)
# [t-SNE] Iteration 4800: error = 1.6018912, gradient norm = 0.0000012 (50 iterations in 0.191s)
# [t-SNE] Iteration 4850: error = 1.6001334, gradient norm = 0.0000012 (50 iterations in 0.153s)
# [t-SNE] Iteration 4900: error = 1.5983208, gradient norm = 0.0000012 (50 iterations in 0.199s)
# [t-SNE] Iteration 4950: error = 1.5965163, gradient norm = 0.0000011 (50 iterations in 0.208s)
# [t-SNE] Iteration 5000: error = 1.5947229, gradient norm = 0.0000011 (50 iterations in 0.220s)
# [t-SNE] Iteration 5050: error = 1.5928661, gradient norm = 0.0000011 (50 iterations in 0.198s)
# [t-SNE] Iteration 5100: error = 1.5912136, gradient norm = 0.0000011 (50 iterations in 0.229s)
# [t-SNE] Iteration 5150: error = 1.5894963, gradient norm = 0.0000011 (50 iterations in 0.218s)
# [t-SNE] Iteration 5200: error = 1.5876669, gradient norm = 0.0000011 (50 iterations in 0.233s)
# [t-SNE] Iteration 5250: error = 1.5859711, gradient norm = 0.0000011 (50 iterations in 0.220s)
# [t-SNE] Iteration 5300: error = 1.5841854, gradient norm = 0.0000010 (50 iterations in 0.266s)
# [t-SNE] Iteration 5350: error = 1.5824867, gradient norm = 0.0000010 (50 iterations in 0.253s)
# [t-SNE] Iteration 5400: error = 1.5807813, gradient norm = 0.0000010 (50 iterations in 0.255s)
# [t-SNE] Iteration 5450: error = 1.5790021, gradient norm = 0.0000010 (50 iterations in 0.230s)
# [t-SNE] Iteration 5500: error = 1.5772220, gradient norm = 0.0000010 (50 iterations in 0.206s)
# [t-SNE] Iteration 5550: error = 1.5753868, gradient norm = 0.0000010 (50 iterations in 0.273s)
# [t-SNE] Iteration 5600: error = 1.5737250, gradient norm = 0.0000010 (50 iterations in 0.249s)
# [t-SNE] Iteration 5650: error = 1.5720177, gradient norm = 0.0000010 (50 iterations in 0.218s)
# [t-SNE] Iteration 5700: error = 1.5703504, gradient norm = 0.0000009 (50 iterations in 0.161s)
# [t-SNE] Iteration 5750: error = 1.5686500, gradient norm = 0.0000009 (50 iterations in 0.156s)
# [t-SNE] Iteration 5800: error = 1.5668406, gradient norm = 0.0000009 (50 iterations in 0.155s)
# [t-SNE] Iteration 5850: error = 1.5653026, gradient norm = 0.0000009 (50 iterations in 0.163s)
# [t-SNE] Iteration 5900: error = 1.5634130, gradient norm = 0.0000009 (50 iterations in 0.139s)
# [t-SNE] Iteration 5950: error = 1.5615425, gradient norm = 0.0000009 (50 iterations in 0.161s)
# [t-SNE] Iteration 6000: error = 1.5595324, gradient norm = 0.0000009 (50 iterations in 0.142s)
# [t-SNE] Iteration 6050: error = 1.5576059, gradient norm = 0.0000009 (50 iterations in 0.151s)
# [t-SNE] Iteration 6100: error = 1.5554842, gradient norm = 0.0000009 (50 iterations in 0.152s)
# [t-SNE] Iteration 6150: error = 1.5530672, gradient norm = 0.0000010 (50 iterations in 0.160s)
# [t-SNE] Iteration 6200: error = 1.5504211, gradient norm = 0.0000010 (50 iterations in 0.155s)
# [t-SNE] Iteration 6250: error = 1.5472915, gradient norm = 0.0000011 (50 iterations in 0.157s)
# [t-SNE] Iteration 6300: error = 1.5451324, gradient norm = 0.0000008 (50 iterations in 0.159s)
# [t-SNE] Iteration 6350: error = 1.5433787, gradient norm = 0.0000008 (50 iterations in 0.158s)
# [t-SNE] Iteration 6400: error = 1.5417186, gradient norm = 0.0000008 (50 iterations in 0.143s)
# [t-SNE] Iteration 6450: error = 1.5400709, gradient norm = 0.0000008 (50 iterations in 0.179s)
# [t-SNE] Iteration 6500: error = 1.5382711, gradient norm = 0.0000008 (50 iterations in 0.211s)
# [t-SNE] Iteration 6550: error = 1.5364618, gradient norm = 0.0000008 (50 iterations in 0.229s)
# [t-SNE] Iteration 6600: error = 1.5344745, gradient norm = 0.0000008 (50 iterations in 0.213s)
# [t-SNE] Iteration 6650: error = 1.5329317, gradient norm = 0.0000008 (50 iterations in 0.192s)
# [t-SNE] Iteration 6700: error = 1.5312357, gradient norm = 0.0000008 (50 iterations in 0.225s)
# [t-SNE] Iteration 6750: error = 1.5297338, gradient norm = 0.0000008 (50 iterations in 0.211s)
# [t-SNE] Iteration 6800: error = 1.5280672, gradient norm = 0.0000008 (50 iterations in 0.214s)
# [t-SNE] Iteration 6850: error = 1.5264823, gradient norm = 0.0000008 (50 iterations in 0.196s)
# [t-SNE] Iteration 6900: error = 1.5250671, gradient norm = 0.0000007 (50 iterations in 0.213s)
# [t-SNE] Iteration 6950: error = 1.5235451, gradient norm = 0.0000007 (50 iterations in 0.175s)
# [t-SNE] Iteration 7000: error = 1.5220103, gradient norm = 0.0000007 (50 iterations in 0.207s)
# [t-SNE] Iteration 7050: error = 1.5202436, gradient norm = 0.0000007 (50 iterations in 0.280s)
# [t-SNE] Iteration 7100: error = 1.5186981, gradient norm = 0.0000007 (50 iterations in 0.277s)
# [t-SNE] Iteration 7150: error = 1.5171695, gradient norm = 0.0000007 (50 iterations in 0.247s)
# [t-SNE] Iteration 7200: error = 1.5155734, gradient norm = 0.0000007 (50 iterations in 0.162s)
# [t-SNE] Iteration 7250: error = 1.5142279, gradient norm = 0.0000007 (50 iterations in 0.175s)
# [t-SNE] Iteration 7300: error = 1.5126880, gradient norm = 0.0000007 (50 iterations in 0.171s)
# [t-SNE] Iteration 7350: error = 1.5112164, gradient norm = 0.0000007 (50 iterations in 0.176s)
# [t-SNE] Iteration 7400: error = 1.5098176, gradient norm = 0.0000007 (50 iterations in 0.148s)
# [t-SNE] Iteration 7450: error = 1.5080799, gradient norm = 0.0000007 (50 iterations in 0.178s)
# [t-SNE] Iteration 7500: error = 1.5065334, gradient norm = 0.0000007 (50 iterations in 0.152s)
# [t-SNE] Iteration 7550: error = 1.5050936, gradient norm = 0.0000007 (50 iterations in 0.173s)
# [t-SNE] Iteration 7600: error = 1.5035871, gradient norm = 0.0000006 (50 iterations in 0.164s)
# [t-SNE] Iteration 7650: error = 1.5021982, gradient norm = 0.0000006 (50 iterations in 0.170s)
# [t-SNE] Iteration 7700: error = 1.5007513, gradient norm = 0.0000006 (50 iterations in 0.165s)
# [t-SNE] Iteration 7750: error = 1.4992882, gradient norm = 0.0000006 (50 iterations in 0.168s)
# [t-SNE] Iteration 7800: error = 1.4976565, gradient norm = 0.0000006 (50 iterations in 0.164s)
# [t-SNE] Iteration 7850: error = 1.4961654, gradient norm = 0.0000006 (50 iterations in 0.159s)
# [t-SNE] Iteration 7900: error = 1.4946945, gradient norm = 0.0000006 (50 iterations in 0.176s)
# [t-SNE] Iteration 7950: error = 1.4931383, gradient norm = 0.0000006 (50 iterations in 0.168s)
# [t-SNE] Iteration 8000: error = 1.4915963, gradient norm = 0.0000006 (50 iterations in 0.155s)
# [t-SNE] Iteration 8050: error = 1.4899360, gradient norm = 0.0000006 (50 iterations in 0.163s)
# [t-SNE] Iteration 8100: error = 1.4883410, gradient norm = 0.0000006 (50 iterations in 0.154s)
# [t-SNE] Iteration 8150: error = 1.4867644, gradient norm = 0.0000006 (50 iterations in 0.175s)
# [t-SNE] Iteration 8200: error = 1.4854288, gradient norm = 0.0000006 (50 iterations in 0.162s)
# [t-SNE] Iteration 8250: error = 1.4838593, gradient norm = 0.0000006 (50 iterations in 0.179s)
# [t-SNE] Iteration 8300: error = 1.4821707, gradient norm = 0.0000006 (50 iterations in 0.145s)
# [t-SNE] Iteration 8350: error = 1.4805537, gradient norm = 0.0000006 (50 iterations in 0.200s)
# [t-SNE] Iteration 8400: error = 1.4788197, gradient norm = 0.0000006 (50 iterations in 0.224s)
# [t-SNE] Iteration 8450: error = 1.4772024, gradient norm = 0.0000006 (50 iterations in 0.228s)
# [t-SNE] Iteration 8500: error = 1.4755899, gradient norm = 0.0000006 (50 iterations in 0.272s)
# [t-SNE] Iteration 8550: error = 1.4739054, gradient norm = 0.0000006 (50 iterations in 0.170s)
# [t-SNE] Iteration 8600: error = 1.4721689, gradient norm = 0.0000006 (50 iterations in 0.314s)
# [t-SNE] Iteration 8650: error = 1.4704632, gradient norm = 0.0000006 (50 iterations in 0.428s)
# [t-SNE] Iteration 8700: error = 1.4689548, gradient norm = 0.0000006 (50 iterations in 0.261s)
# [t-SNE] Iteration 8750: error = 1.4673203, gradient norm = 0.0000006 (50 iterations in 0.233s)
# [t-SNE] Iteration 8800: error = 1.4657325, gradient norm = 0.0000006 (50 iterations in 0.246s)
# [t-SNE] Iteration 8850: error = 1.4641867, gradient norm = 0.0000005 (50 iterations in 0.296s)
# [t-SNE] Iteration 8900: error = 1.4626707, gradient norm = 0.0000005 (50 iterations in 0.246s)
# [t-SNE] Iteration 8950: error = 1.4613389, gradient norm = 0.0000005 (50 iterations in 0.236s)
# [t-SNE] Iteration 9000: error = 1.4598745, gradient norm = 0.0000005 (50 iterations in 0.216s)
# [t-SNE] Iteration 9050: error = 1.4583499, gradient norm = 0.0000005 (50 iterations in 0.247s)
# [t-SNE] Iteration 9100: error = 1.4569502, gradient norm = 0.0000005 (50 iterations in 0.255s)
# [t-SNE] Iteration 9150: error = 1.4554118, gradient norm = 0.0000005 (50 iterations in 0.294s)
# [t-SNE] Iteration 9200: error = 1.4539853, gradient norm = 0.0000005 (50 iterations in 0.232s)
# [t-SNE] Iteration 9250: error = 1.4525543, gradient norm = 0.0000005 (50 iterations in 0.246s)
# [t-SNE] Iteration 9300: error = 1.4511583, gradient norm = 0.0000005 (50 iterations in 0.233s)
# [t-SNE] Iteration 9350: error = 1.4497012, gradient norm = 0.0000005 (50 iterations in 0.236s)
# [t-SNE] Iteration 9400: error = 1.4483032, gradient norm = 0.0000005 (50 iterations in 0.226s)
# [t-SNE] Iteration 9450: error = 1.4468795, gradient norm = 0.0000005 (50 iterations in 0.216s)
# [t-SNE] Iteration 9500: error = 1.4454561, gradient norm = 0.0000005 (50 iterations in 0.177s)
# [t-SNE] Iteration 9550: error = 1.4440382, gradient norm = 0.0000005 (50 iterations in 0.169s)
# [t-SNE] Iteration 9600: error = 1.4426738, gradient norm = 0.0000005 (50 iterations in 0.164s)
# [t-SNE] Iteration 9650: error = 1.4412889, gradient norm = 0.0000005 (50 iterations in 0.166s)
# [t-SNE] Iteration 9700: error = 1.4399483, gradient norm = 0.0000005 (50 iterations in 0.160s)
# [t-SNE] Iteration 9750: error = 1.4385648, gradient norm = 0.0000005 (50 iterations in 0.161s)
# [t-SNE] Iteration 9800: error = 1.4372102, gradient norm = 0.0000005 (50 iterations in 0.241s)
# [t-SNE] Iteration 9850: error = 1.4358814, gradient norm = 0.0000005 (50 iterations in 0.353s)
# [t-SNE] Iteration 9900: error = 1.4344953, gradient norm = 0.0000005 (50 iterations in 0.209s)
# [t-SNE] Iteration 9950: error = 1.4331390, gradient norm = 0.0000005 (50 iterations in 0.178s)
# [t-SNE] Iteration 10000: error = 1.4317867, gradient norm = 0.0000005 (50 iterations in 0.163s)
# [t-SNE] KL divergence after 10000 iterations: 1.431787
# --- 40.68877029418945 seconds ---

# %%
df=pd.DataFrame(all_word_vectors_matrix_3d,columns=['X','Y', 'Z'])

df.head(10)

train.head()

df.reset_index(drop=True, inplace=True)
train.reset_index(drop=True, inplace=True)

# %%
three_dimensional_songs = pd.concat([train, df], axis=1)

three_dimensional_songs.head()
# Out:
#    id artista                       cancion                album  \
# 0  29    Nach  Cuando ya no esté (con Klau)            Almanauta
# 1  27    SFDK          El perro anda suelto  Desde los chiqueros
# 2   6  Rayden     El violinista del titanic      En alma y hueso
# 3  47  Rayden     Imperdible (con Sidecars)             Antónimo
# 4  28    Nach                    Manifiesto   Un día en suburbia
#
#                                                letra  anyo  visitas  \
# 0  [Nach]\n¿Cuánto tiempo me queda? Los años vuel...  2018     3823
# 1  Hoy ya somos la pareja con compatibilidad, y v...  2000     3841
# 2  Tras el duro invier(_) siempre sale el sol de ...  2014     2447
# 3  Podré perder el norte,\nPodré perderme en dond...  2017    21931
# 4  Mi padre es el sol, mi madre la luna\nmi herma...  2008    21397
#
#                                          song_vector           X           Y  \
# 0  [[-0.045673825, 0.11685847, 0.18566772, -0.196... -242.748611 -149.885117
# 1  [[-0.039533764, 0.07019628, 0.14477897, -0.155...  290.997314  -92.063995
# 2  [[-0.033285853, 0.13485606, 0.1683339, -0.1798... -199.720444 -297.669434
# 3  [[-0.030984491, 0.14549348, 0.19831865, -0.185... -314.887756 -401.349518
# 4  [[-0.053237442, 0.097117715, 0.16198772, -0.17... -213.315598  207.021698
#
#             Z
# 0 -417.295929
# 1  320.812408
# 2 -229.728500
# 3  -55.033806
# 4   71.046303

# %%
import plotly.express as px

fig = px.scatter_3d(three_dimensional_songs, x='X', y='Y', z='Z',
              color='artista')
fig.show()

# %% [markdown]
# ### Se observa como, en este caso, el algoritmo es capaz de separar mejor a los distintos raperos

# %% [markdown]
# ## Noticias 2D
# En este caso, lo que se busca con el clustering es comprobar si somos capaces de diferenciar la sección a la que pertenece la noticia

# %%
import time
news = pd.read_csv("songlyrics/noticias.csv", sep='\|', encoding='UTF-8').groupby('NEW_TITLE', as_index=False).max()

start_time = time.time()

news['news_vector'] = [clean(normalize(str(new))) for new in news['NEW']]
news['news_vector'] = news['news_vector'].apply(create_vector)
news = news[news['news_vector'] != "No words in vocab"]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# : DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# --- 2.3117504119873047 seconds ---
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\pablo\Anaconda3\envs\No-estructurado-bea\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
news_vectors = []
from sklearn.model_selection import train_test_split

train, test = train_test_split(news, test_size = 0.2)


for news_vector in train['news_vector']:
    news_vectors.append(news_vector)

train.head(5)
# Out:
#                                              NEW_TITLE     SECTION  \
# 526                        ¡Pedro, Pedro, encadénanos!     opinion
# 375  MasterChef 8 y la rebelión que acabó en una cr...  television
# 184  El Gobierno gana poder en el deporte y lleva a...    deportes
# 391  Muere José María Castillo, productor ejecutivo...  television
# 188  El Gobierno quita el límite de suspensos que f...      espana
#
#                                            SECTION_URL  \
# 526  https://www.elmundo.es/opinion.html?intcmp=MEN...
# 375  https://www.elmundo.es/television.html?intcmp=...
# 184  https://www.elmundo.es/deportes.html?intcmp=ME...
# 391  https://www.elmundo.es/television.html?intcmp=...
# 188  https://www.elmundo.es/espana.html?intcmp=MENU...
#
#                                                NEW_URL  \
# 526  https://www.elmundo.es/opinion/2020/04/15/5e97...
# 375  https://www.elmundo.es/television/momentvs/202...
# 184  https://www.elmundo.es/deportes/futbol/primera...
# 391  https://www.elmundo.es/television/2020/04/12/5...
# 188  https://www.elmundo.es/espana/2020/04/24/5ea2b...
#
#                                                    NEW  \
# 526  Al final el pobre Sánchez no va a tener más re...
# 375  "Cuenta la leyenda que allá por el 2020, en pl...
# 184  "Los pactos alcanzados en la reunión entre Ire...
# 391  "Este domingo ha fallecido José María Castillo...
# 188  "El Gobierno ha quitado ""de forma excepcional...
#
#                                            news_vector
# 526  [[-0.018448656, 0.101849996, 0.18082964, -0.16...
# 375  [[-0.037350487, 0.107858576, 0.19142526, -0.17...
# 184  [[-0.040540792, 0.10750827, 0.17678349, -0.155...
# 391  [[0.0018487575, 0.11295477, 0.14102325, -0.147...
# 188  [[-0.062308613, 0.13607141, 0.18420309, -0.187...

# %%
X = np.array(news_vectors).reshape((int(len(news_vectors)*num_features/num_features), num_features))

start_time = time.time()
tsne = sklearn.manifold.TSNE(n_components=2, n_iter=30000, random_state=0, verbose=10)

all_word_vectors_matrix_2d = tsne.fit_transform(X)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 423 samples in 0.006s...
# [t-SNE] Computed neighbors for 423 samples in 0.051s...
# [t-SNE] Computed conditional probabilities for sample 423 / 423
# [t-SNE] Mean sigma: 0.059898
# [t-SNE] Computed conditional probabilities in 0.024s
# [t-SNE] Iteration 50: error = 82.0115204, gradient norm = 0.4252600 (50 iterations in 0.139s)
# [t-SNE] Iteration 100: error = 86.1990051, gradient norm = 0.4118958 (50 iterations in 0.150s)
# [t-SNE] Iteration 150: error = 87.2386246, gradient norm = 0.3672943 (50 iterations in 0.146s)
# [t-SNE] Iteration 200: error = 85.1166763, gradient norm = 0.4023973 (50 iterations in 0.139s)
# [t-SNE] Iteration 250: error = 84.7281036, gradient norm = 0.3776489 (50 iterations in 0.150s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.728104
# [t-SNE] Iteration 300: error = 1.6459476, gradient norm = 0.0054623 (50 iterations in 0.118s)
# [t-SNE] Iteration 350: error = 1.4961488, gradient norm = 0.0020255 (50 iterations in 0.113s)
# [t-SNE] Iteration 400: error = 1.4487808, gradient norm = 0.0010774 (50 iterations in 0.132s)
# [t-SNE] Iteration 450: error = 1.4232893, gradient norm = 0.0011461 (50 iterations in 0.142s)
# [t-SNE] Iteration 500: error = 1.4045507, gradient norm = 0.0006163 (50 iterations in 0.118s)
# [t-SNE] Iteration 550: error = 1.3907661, gradient norm = 0.0011037 (50 iterations in 0.114s)
# [t-SNE] Iteration 600: error = 1.3837404, gradient norm = 0.0003580 (50 iterations in 0.116s)
# [t-SNE] Iteration 650: error = 1.3746562, gradient norm = 0.0006062 (50 iterations in 0.109s)
# [t-SNE] Iteration 700: error = 1.3664618, gradient norm = 0.0004194 (50 iterations in 0.112s)
# [t-SNE] Iteration 750: error = 1.3615332, gradient norm = 0.0004700 (50 iterations in 0.108s)
# [t-SNE] Iteration 800: error = 1.3424960, gradient norm = 0.0006496 (50 iterations in 0.114s)
# [t-SNE] Iteration 850: error = 1.3406916, gradient norm = 0.0002298 (50 iterations in 0.134s)
# [t-SNE] Iteration 900: error = 1.3386364, gradient norm = 0.0002169 (50 iterations in 0.171s)
# [t-SNE] Iteration 950: error = 1.3375766, gradient norm = 0.0002359 (50 iterations in 0.173s)
# [t-SNE] Iteration 1000: error = 1.3373635, gradient norm = 0.0001269 (50 iterations in 0.149s)
# [t-SNE] Iteration 1050: error = 1.3366864, gradient norm = 0.0002994 (50 iterations in 0.112s)
# [t-SNE] Iteration 1100: error = 1.3357735, gradient norm = 0.0002575 (50 iterations in 0.109s)
# [t-SNE] Iteration 1150: error = 1.3299245, gradient norm = 0.0002666 (50 iterations in 0.114s)
# [t-SNE] Iteration 1200: error = 1.3299574, gradient norm = 0.0001300 (50 iterations in 0.111s)
# [t-SNE] Iteration 1250: error = 1.3298888, gradient norm = 0.0000853 (50 iterations in 0.111s)
# [t-SNE] Iteration 1300: error = 1.3295461, gradient norm = 0.0001114 (50 iterations in 0.108s)
# [t-SNE] Iteration 1350: error = 1.3293967, gradient norm = 0.0000788 (50 iterations in 0.110s)
# [t-SNE] Iteration 1400: error = 1.3292435, gradient norm = 0.0000570 (50 iterations in 0.105s)
# [t-SNE] Iteration 1450: error = 1.3292516, gradient norm = 0.0000524 (50 iterations in 0.109s)
# [t-SNE] Iteration 1500: error = 1.3292950, gradient norm = 0.0000569 (50 iterations in 0.114s)
# [t-SNE] Iteration 1550: error = 1.3293563, gradient norm = 0.0000586 (50 iterations in 0.129s)
# [t-SNE] Iteration 1600: error = 1.3292984, gradient norm = 0.0000494 (50 iterations in 0.131s)
# [t-SNE] Iteration 1650: error = 1.3294286, gradient norm = 0.0000549 (50 iterations in 0.112s)
# [t-SNE] Iteration 1700: error = 1.3293786, gradient norm = 0.0000798 (50 iterations in 0.108s)
# [t-SNE] Iteration 1750: error = 1.3296193, gradient norm = 0.0000705 (50 iterations in 0.108s)
# [t-SNE] Iteration 1750: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1750 iterations: 1.329619
# --- 4.410712957382202 seconds ---

# %%
df=pd.DataFrame(all_word_vectors_matrix_2d,columns=['X','Y'])

df.head(10)

train.head()

df.reset_index(drop=True, inplace=True)
train.reset_index(drop=True, inplace=True)

# %%
two_dimensional_songs = pd.concat([train, df], axis=1)

two_dimensional_songs.head()
# Out:
#                                            NEW_TITLE     SECTION  \
# 0                        ¡Pedro, Pedro, encadénanos!     opinion
# 1  MasterChef 8 y la rebelión que acabó en una cr...  television
# 2  El Gobierno gana poder en el deporte y lleva a...    deportes
# 3  Muere José María Castillo, productor ejecutivo...  television
# 4  El Gobierno quita el límite de suspensos que f...      espana
#
#                                          SECTION_URL  \
# 0  https://www.elmundo.es/opinion.html?intcmp=MEN...
# 1  https://www.elmundo.es/television.html?intcmp=...
# 2  https://www.elmundo.es/deportes.html?intcmp=ME...
# 3  https://www.elmundo.es/television.html?intcmp=...
# 4  https://www.elmundo.es/espana.html?intcmp=MENU...
#
#                                              NEW_URL  \
# 0  https://www.elmundo.es/opinion/2020/04/15/5e97...
# 1  https://www.elmundo.es/television/momentvs/202...
# 2  https://www.elmundo.es/deportes/futbol/primera...
# 3  https://www.elmundo.es/television/2020/04/12/5...
# 4  https://www.elmundo.es/espana/2020/04/24/5ea2b...
#
#                                                  NEW  \
# 0  Al final el pobre Sánchez no va a tener más re...
# 1  "Cuenta la leyenda que allá por el 2020, en pl...
# 2  "Los pactos alcanzados en la reunión entre Ire...
# 3  "Este domingo ha fallecido José María Castillo...
# 4  "El Gobierno ha quitado ""de forma excepcional...
#
#                                          news_vector          X         Y
# 0  [[-0.018448656, 0.101849996, 0.18082964, -0.16... -15.398737 -1.115017
# 1  [[-0.037350487, 0.107858576, 0.19142526, -0.17...  10.991641 -5.949742
# 2  [[-0.040540792, 0.10750827, 0.17678349, -0.155...  -6.965820 -3.349588
# 3  [[0.0018487575, 0.11295477, 0.14102325, -0.147...   9.949397  6.432118
# 4  [[-0.062308613, 0.13607141, 0.18420309, -0.187...  -2.611839 -2.950437

# %%
import plotly.express as px
df = px.data.tips()
fig = px.scatter(two_dimensional_songs, x="X", y="Y", color="SECTION",
                 title="Sacciones de prensa")

fig.show()
# Out:
# <div>
#
#
#             <div id="a5fda088-e3c3-40bb-84c2-146087ca8acb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a5fda088-e3c3-40bb-84c2-146087ca8acb")) {
#                     Plotly.newPlot(
#                         'a5fda088-e3c3-40bb-84c2-146087ca8acb',
#                         [{"hovertemplate": "SECTION=opinion<br>X=%{x}<br>Y=%{y}<extra></extra>", "legendgroup": "opinion", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "opinion", "showlegend": true, "type": "scatter", "x": [-15.398736953735352, -2.2626760005950928, -11.34867000579834, 7.422454357147217, -3.1093316078186035, -5.456836223602295, -13.441328048706055, -3.497255802154541, -1.6260827779769897, -3.479016065597534, -9.672917366027832, -3.361704111099243, -6.259099960327148, 3.416628837585449, -11.968033790588379, -6.224128246307373, -0.9925521612167358, 12.284748077392578, -11.37106704711914, -3.2798337936401367, -11.591294288635254, 7.6391448974609375, 7.708230018615723, -1.2444958686828613, -7.312795639038086, -2.033371925354004, -10.068757057189941, -8.407983779907227, -7.855422019958496, 0.34953543543815613, -13.368319511413574, 12.213581085205078, -12.0873441696167, -2.983989715576172, 6.840596675872803, 4.064581871032715, -14.188109397888184, -11.939929008483887, -0.4679809510707855, 10.752604484558105, -6.948110580444336, -7.509267807006836, -2.0704681873321533, -5.480959892272949, 6.47926664352417, -10.935811996459961, -10.27383804321289, 2.3710453510284424, -6.5488786697387695, 1.6406012773513794, -13.042928695678711, 9.517082214355469, -1.2939077615737915, 5.711635112762451, -1.6246931552886963, -7.5796074867248535, -9.73436164855957], "xaxis": "x", "y": [-1.1150168180465698, -1.8676432371139526, -1.2032297849655151, 7.43164587020874, -1.1887130737304688, -1.169929027557373, 2.4908018112182617, -2.1258723735809326, -2.416023015975952, 10.19820499420166, -0.8464331030845642, -2.336843967437744, -0.3761129379272461, -11.599262237548828, -3.726059913635254, -5.866026401519775, -13.811300277709961, -3.8955328464508057, 5.81510066986084, -12.803205490112305, -1.039411187171936, -6.693403720855713, -8.047865867614746, -1.7265841960906982, 8.038996696472168, 9.432841300964355, 8.982571601867676, -3.5141375064849854, -6.839159965515137, -2.1692965030670166, -0.722783088684082, -6.772887229919434, -7.303624629974365, -5.024470806121826, -7.503206253051758, -0.24029482901096344, -2.4633383750915527, -3.7733852863311768, -4.232537746429443, -4.747090816497803, 7.1326093673706055, -6.371886253356934, -4.14230489730835, -11.216879844665527, -11.196035385131836, 4.025973320007324, -3.392622470855713, -9.198386192321777, -11.349187850952148, -1.300227403640747, -2.0188798904418945, 0.3297887146472931, -4.131165027618408, 7.3971757888793945, -1.5522196292877197, -8.354135513305664, 10.950169563293457], "yaxis": "y"}, {"hovertemplate": "SECTION=television<br>X=%{x}<br>Y=%{y}<extra></extra>", "legendgroup": "television", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "television", "showlegend": true, "type": "scatter", "x": [10.9916410446167, 9.949397087097168, 9.817419052124023, 7.895269870758057, -2.872527599334717, -11.46409797668457, -1.1151407957077026, 7.801987171173096, -11.679604530334473, 10.848546981811523, 7.056766986846924, -11.717129707336426, 9.372275352478027, 11.684683799743652, -4.5214762687683105, 7.869039058685303, 8.525650024414062, -11.501614570617676, -11.692675590515137, -11.72913646697998, -11.555164337158203, 11.654592514038086, -11.496365547180176, -11.716012001037598, 6.832298755645752, -11.66136646270752], "xaxis": "x", "y": [-5.949741840362549, 6.432117938995361, -6.780427932739258, -2.3783345222473145, -3.503390073776245, -9.686905860900879, -10.053828239440918, -2.4469926357269287, -15.0767240524292, -6.127624988555908, -1.7722172737121582, -15.004690170288086, 5.743218421936035, -6.019225597381592, 3.2969510555267334, 3.1238017082214355, -2.2517714500427246, -14.774626731872559, -14.922126770019531, -15.015327453613281, -8.468892097473145, -6.1601715087890625, -9.155376434326172, -15.043062210083008, -1.5713025331497192, -15.05923843383789], "yaxis": "y"}, {"hovertemplate": "SECTION=deportes<br>X=%{x}<br>Y=%{y}<extra></extra>", " ...

# %% [markdown]
# #### En este caso, el algoritmo no es capaz de separar claramente las 8 secciones de prensa, pero si que se ve claramente que muchas de ellas tienen un lenguaje muy parecido, como la sección de tecnología, que todos sus artículos se ubicas en el cuadrante inferior, el de cultura, que acapara prácticamente todo el cuadrante superior derecho. Otros, como ciencia y salud está disperso entre todos los cuadrantes, y, en el caso de televisión, se separa en dos grupos.

# %%
start_time = time.time()
tsne = sklearn.manifold.TSNE(n_components=3, n_iter=30000, random_state=0, verbose=10)

all_word_vectors_matrix_3d = tsne.fit_transform(X)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#  = 0.0000002 (50 iterations in 0.296s)
# [t-SNE] Iteration 19700: error = 1.6363192, gradient norm = 0.0000002 (50 iterations in 0.304s)
# [t-SNE] Iteration 19750: error = 1.6359529, gradient norm = 0.0000002 (50 iterations in 0.275s)
# [t-SNE] Iteration 19800: error = 1.6355671, gradient norm = 0.0000002 (50 iterations in 0.320s)
# [t-SNE] Iteration 19850: error = 1.6352118, gradient norm = 0.0000002 (50 iterations in 0.382s)
# [t-SNE] Iteration 19900: error = 1.6348723, gradient norm = 0.0000002 (50 iterations in 0.309s)
# [t-SNE] Iteration 19950: error = 1.6345243, gradient norm = 0.0000002 (50 iterations in 0.292s)
# [t-SNE] Iteration 20000: error = 1.6342288, gradient norm = 0.0000002 (50 iterations in 0.279s)
# [t-SNE] Iteration 20050: error = 1.6338726, gradient norm = 0.0000002 (50 iterations in 0.362s)
# [t-SNE] Iteration 20100: error = 1.6334019, gradient norm = 0.0000002 (50 iterations in 0.350s)
# [t-SNE] Iteration 20150: error = 1.6330438, gradient norm = 0.0000002 (50 iterations in 0.327s)
# [t-SNE] Iteration 20200: error = 1.6326740, gradient norm = 0.0000002 (50 iterations in 0.285s)
# [t-SNE] Iteration 20250: error = 1.6323230, gradient norm = 0.0000002 (50 iterations in 0.259s)
# [t-SNE] Iteration 20300: error = 1.6321250, gradient norm = 0.0000002 (50 iterations in 0.262s)
# [t-SNE] Iteration 20350: error = 1.6317687, gradient norm = 0.0000002 (50 iterations in 0.257s)
# [t-SNE] Iteration 20400: error = 1.6313651, gradient norm = 0.0000002 (50 iterations in 0.264s)
# [t-SNE] Iteration 20450: error = 1.6310099, gradient norm = 0.0000002 (50 iterations in 0.262s)
# [t-SNE] Iteration 20500: error = 1.6306652, gradient norm = 0.0000002 (50 iterations in 0.264s)
# [t-SNE] Iteration 20550: error = 1.6303220, gradient norm = 0.0000002 (50 iterations in 0.260s)
# [t-SNE] Iteration 20600: error = 1.6299710, gradient norm = 0.0000002 (50 iterations in 0.265s)
# [t-SNE] Iteration 20650: error = 1.6296175, gradient norm = 0.0000002 (50 iterations in 0.267s)
# [t-SNE] Iteration 20700: error = 1.6292663, gradient norm = 0.0000002 (50 iterations in 0.275s)
# [t-SNE] Iteration 20750: error = 1.6289238, gradient norm = 0.0000002 (50 iterations in 0.347s)
# [t-SNE] Iteration 20800: error = 1.6285725, gradient norm = 0.0000002 (50 iterations in 0.388s)
# [t-SNE] Iteration 20850: error = 1.6282223, gradient norm = 0.0000002 (50 iterations in 0.348s)
# [t-SNE] Iteration 20900: error = 1.6278872, gradient norm = 0.0000002 (50 iterations in 0.315s)
# [t-SNE] Iteration 20950: error = 1.6275467, gradient norm = 0.0000002 (50 iterations in 0.297s)
# [t-SNE] Iteration 21000: error = 1.6272168, gradient norm = 0.0000002 (50 iterations in 0.286s)
# [t-SNE] Iteration 21050: error = 1.6268698, gradient norm = 0.0000002 (50 iterations in 0.294s)
# [t-SNE] Iteration 21100: error = 1.6265367, gradient norm = 0.0000002 (50 iterations in 0.316s)
# [t-SNE] Iteration 21150: error = 1.6261940, gradient norm = 0.0000002 (50 iterations in 0.305s)
# [t-SNE] Iteration 21200: error = 1.6258417, gradient norm = 0.0000002 (50 iterations in 0.304s)
# [t-SNE] Iteration 21250: error = 1.6255052, gradient norm = 0.0000002 (50 iterations in 0.282s)
# [t-SNE] Iteration 21300: error = 1.6252017, gradient norm = 0.0000002 (50 iterations in 0.259s)
# [t-SNE] Iteration 21350: error = 1.6248758, gradient norm = 0.0000002 (50 iterations in 0.266s)
# [t-SNE] Iteration 21400: error = 1.6245430, gradient norm = 0.0000002 (50 iterations in 0.263s)
# [t-SNE] Iteration 21450: error = 1.6242245, gradient norm = 0.0000002 (50 iterations in 0.269s)
# [t-SNE] Iteration 21500: error = 1.6238968, gradient norm = 0.0000002 (50 iterations in 0.299s)
# [t-SNE] Iteration 21550: error = 1.6235765, gradient norm = 0.0000002 (50 iterations in 0.299s)
# [t-SNE] Iteration 21600: error = 1.6232522, gradient norm = 0.0000002 (50 iterations in 0.279s)
# [t-SNE] Iteration 21650: error = 1.6228808, gradient norm = 0.0000002 (50 iterations in 0.310s)
# [t-SNE] Iteration 21700: error = 1.6225475, gradient norm = 0.0000002 (50 iterations in 0.345s)
# [t-SNE] Iteration 21750: error = 1.6222688, gradient norm = 0.0000002 (50 iterations in 0.398s)
# [t-SNE] Iteration 21800: error = 1.6219494, gradient norm = 0.0000002 (50 iterations in 0.416s)
# [t-SNE] Iteration 21850: error = 1.6216303, gradient norm = 0.0000002 (50 iterations in 0.294s)
# [t-SNE] Iteration 21900: error = 1.6213104, gradient norm = 0.0000002 (50 iterations in 0.255s)
# [t-SNE] Iteration 21950: error = 1.6209338, gradient norm = 0.0000002 (50 iterations in 0.328s)
# [t-SNE] Iteration 22000: error = 1.6206211, gradient norm = 0.0000002 (50 iterations in 0.362s)
# [t-SNE] Iteration 22050: error = 1.6203449, gradient norm = 0.0000002 (50 iterations in 0.282s)
# [t-SNE] Iteration 22100: error = 1.6200137, gradient norm = 0.0000002 (50 iterations in 0.276s)
# [t-SNE] Iteration 22150: error = 1.6196936, gradient norm = 0.0000002 (50 iterations in 0.309s)
# [t-SNE] Iteration 22200: error = 1.6193602, gradient norm = 0.0000002 (50 iterations in 0.313s)
# [t-SNE] Iteration 22250: error = 1.6190462, gradient norm = 0.0000002 (50 iterations in 0.315s)
# [t-SNE] Iteration 22300: error = 1.6187153, gradient norm = 0.0000002 (50 iterations in 0.294s)
# [t-SNE] Iteration 22350: error = 1.6184007, gradient norm = 0.0000002 (50 iterations in 0.326s)
# [t-SNE] Iteration 22400: error = 1.6180613, gradient norm = 0.0000002 (50 iterations in 0.277s)
# [t-SNE] Iteration 22450: error = 1.6177453, gradient norm = 0.0000002 (50 iterations in 0.300s)
# [t-SNE] Iteration 22500: error = 1.6174024, gradient norm = 0.0000002 (50 iterations in 0.306s)
# [t-SNE] Iteration 22550: error = 1.6170697, gradient norm = 0.0000002 (50 iterations in 0.334s)
# [t-SNE] Iteration 22600: error = 1.6167620, gradient norm = 0.0000002 (50 iterations in 0.421s)
# [t-SNE] Iteration 22650: error = 1.6164750, gradient norm = 0.0000002 (50 iterations in 0.360s)
# [t-SNE] Iteration 22700: error = 1.6161700, gradient norm = 0.0000002 (50 iterations in 0.303s)
# [t-SNE] Iteration 22750: error = 1.6158400, gradient norm = 0.0000002 (50 iterations in 0.313s)
# [t-SNE] Iteration 22800: error = 1.6155266, gradient norm = 0.0000002 (50 iterations in 0.284s)
# [t-SNE] Iteration 22850: error = 1.6152219, gradient norm = 0.0000002 (50 iterations in 0.270s)
# [t-SNE] Iteration 22900: error = 1.6149197, gradient norm = 0.0000002 (50 iterations in 0.262s)
# [t-SNE] Iteration 22950: error = 1.6146240, gradient norm = 0.0000002 (50 iterations in 0.288s)
# [t-SNE] Iteration 23000: error = 1.6142763, gradient norm = 0.0000002 (50 iterations in 0.302s)
# [t-SNE] Iteration 23050: error = 1.6139777, gradient norm = 0.0000002 (50 iterations in 0.300s)
# [t-SNE] Iteration 23100: error = 1.6136791, gradient norm = 0.0000002 (50 iterations in 0.260s)
# [t-SNE] Iteration 23150: error = 1.6133877, gradient norm = 0.0000002 (50 iterations in 0.265s)
# [t-SNE] Iteration 23200: error = 1.6130986, gradient norm = 0.0000002 (50 iterations in 0.289s)
# [t-SNE] Iteration 23250: error = 1.6128199, gradient norm = 0.0000002 (50 iterations in 0.290s)
# [t-SNE] Iteration 23300: error = 1.6125240, gradient norm = 0.0000002 (50 iterations in 0.272s)
# [t-SNE] Iteration 23350: error = 1.6122043, gradient norm = 0.0000002 (50 iterations in 0.269s)
# [t-SNE] Iteration 23400: error = 1.6118841, gradient norm = 0.0000002 (50 iterations in 0.255s)
# [t-SNE] Iteration 23450: error = 1.6116289, gradient norm = 0.0000002 (50 iterations in 0.292s)
# [t-SNE] Iteration 23500: error = 1.6114070, gradient norm = 0.0000002 (50 iterations in 0.292s)
# [t-SNE] Iteration 23550: error = 1.6111330, gradient norm = 0.0000002 (50 iterations in 0.369s)
# [t-SNE] Iteration 23600: error = 1.6108623, gradient norm = 0.0000002 (50 iterations in 0.343s)
# [t-SNE] Iteration 23650: error = 1.6105818, gradient norm = 0.0000002 (50 iterations in 0.323s)
# [t-SNE] Iteration 23700: error = 1.6102991, gradient norm = 0.0000002 (50 iterations in 0.300s)
# [t-SNE] Iteration 23750: error = 1.6100194, gradient norm = 0.0000002 (50 iterations in 0.272s)
# [t-SNE] Iteration 23800: error = 1.6097381, gradient norm = 0.0000001 (50 iterations in 0.287s)
# [t-SNE] Iteration 23850: error = 1.6094398, gradient norm = 0.0000001 (50 iterations in 0.261s)
# [t-SNE] Iteration 23900: error = 1.6091523, gradient norm = 0.0000001 (50 iterations in 0.258s)
# [t-SNE] Iteration 23950: error = 1.6088775, gradient norm = 0.0000001 (50 iterations in 0.256s)
# [t-SNE] Iteration 24000: error = 1.6085855, gradient norm = 0.0000001 (50 iterations in 0.256s)
# [t-SNE] Iteration 24050: error = 1.6083053, gradient norm = 0.0000001 (50 iterations in 0.270s)
# [t-SNE] Iteration 24100: error = 1.6080714, gradient norm = 0.0000001 (50 iterations in 0.290s)
# [t-SNE] Iteration 24150: error = 1.6077973, gradient norm = 0.0000001 (50 iterations in 0.292s)
# [t-SNE] Iteration 24200: error = 1.6075685, gradient norm = 0.0000001 (50 iterations in 0.297s)
# [t-SNE] Iteration 24250: error = 1.6073922, gradient norm = 0.0000001 (50 iterations in 0.302s)
# [t-SNE] Iteration 24300: error = 1.6071162, gradient norm = 0.0000001 (50 iterations in 0.291s)
# [t-SNE] Iteration 24350: error = 1.6068528, gradient norm = 0.0000001 (50 iterations in 0.294s)
# [t-SNE] Iteration 24400: error = 1.6065884, gradient norm = 0.0000001 (50 iterations in 0.307s)
# [t-SNE] Iteration 24450: error = 1.6062042, gradient norm = 0.0000001 (50 iterations in 0.297s)
# [t-SNE] Iteration 24500: error = 1.6059458, gradient norm = 0.0000001 (50 iterations in 0.403s)
# [t-SNE] Iteration 24550: error = 1.6056533, gradient norm = 0.0000001 (50 iterations in 0.375s)
# [t-SNE] Iteration 24600: error = 1.6053855, gradient norm = 0.0000001 (50 iterations in 0.322s)
# [t-SNE] Iteration 24650: error = 1.6051986, gradient norm = 0.0000001 (50 iterations in 0.294s)
# [t-SNE] Iteration 24700: error = 1.6049292, gradient norm = 0.0000001 (50 iterations in 0.309s)
# [t-SNE] Iteration 24750: error = 1.6046376, gradient norm = 0.0000001 (50 iterations in 0.289s)
# [t-SNE] Iteration 24800: error = 1.6043893, gradient norm = 0.0000001 (50 iterations in 0.303s)
# [t-SNE] Iteration 24850: error = 1.6041228, gradient norm = 0.0000001 (50 iterations in 0.264s)
# [t-SNE] Iteration 24900: error = 1.6038644, gradient norm = 0.0000001 (50 iterations in 0.255s)
# [t-SNE] Iteration 24950: error = 1.6036152, gradient norm = 0.0000001 (50 iterations in 0.286s)
# [t-SNE] Iteration 25000: error = 1.6033621, gradient norm = 0.0000001 (50 iterations in 0.281s)
# [t-SNE] Iteration 25050: error = 1.6031233, gradient norm = 0.0000001 (50 iterations in 0.286s)
# [t-SNE] Iteration 25100: error = 1.6028636, gradient norm = 0.0000001 (50 iterations in 0.271s)
# [t-SNE] Iteration 25150: error = 1.6026140, gradient norm = 0.0000001 (50 iterations in 0.270s)
# [t-SNE] Iteration 25200: error = 1.6023065, gradient norm = 0.0000001 (50 iterations in 0.266s)
# [t-SNE] Iteration 25250: error = 1.6020535, gradient norm = 0.0000001 (50 iterations in 0.282s)
# [t-SNE] Iteration 25300: error = 1.6017935, gradient norm = 0.0000001 (50 iterations in 0.275s)
# [t-SNE] Iteration 25350: error = 1.6015475, gradient norm = 0.0000001 (50 iterations in 0.298s)
# [t-SNE] Iteration 25400: error = 1.6012921, gradient norm = 0.0000001 (50 iterations in 0.318s)
# [t-SNE] Iteration 25450: error = 1.6010430, gradient norm = 0.0000001 (50 iterations in 0.392s)
# [t-SNE] Iteration 25500: error = 1.6007795, gradient norm = 0.0000001 (50 iterations in 0.362s)
# [t-SNE] Iteration 25550: error = 1.6005228, gradient norm = 0.0000001 (50 iterations in 0.332s)
# [t-SNE] Iteration 25600: error = 1.6002823, gradient norm = 0.0000001 (50 iterations in 0.265s)
# [t-SNE] Iteration 25650: error = 1.6000392, gradient norm = 0.0000001 (50 iterations in 0.262s)
# [t-SNE] Iteration 25700: error = 1.5997902, gradient norm = 0.0000001 (50 iterations in 0.256s)
# [t-SNE] Iteration 25750: error = 1.5995121, gradient norm = 0.0000001 (50 iterations in 0.255s)
# [t-SNE] Iteration 25800: error = 1.5994005, gradient norm = 0.0000001 (50 iterations in 0.249s)
# [t-SNE] Iteration 25850: error = 1.5990574, gradient norm = 0.0000001 (50 iterations in 0.264s)
# [t-SNE] Iteration 25900: error = 1.5987967, gradient norm = 0.0000001 (50 iterations in 0.249s)
# [t-SNE] Iteration 25950: error = 1.5986353, gradient norm = 0.0000001 (50 iterations in 0.257s)
# [t-SNE] Iteration 26000: error = 1.5983803, gradient norm = 0.0000001 (50 iterations in 0.261s)
# [t-SNE] Iteration 26050: error = 1.5981075, gradient norm = 0.0000001 (50 iterations in 0.275s)
# [t-SNE] Iteration 26100: error = 1.5978826, gradient norm = 0.0000001 (50 iterations in 0.271s)
# [t-SNE] Iteration 26150: error = 1.5975988, gradient norm = 0.0000001 (50 iterations in 0.290s)
# [t-SNE] Iteration 26200: error = 1.5973463, gradient norm = 0.0000001 (50 iterations in 0.313s)
# [t-SNE] Iteration 26250: error = 1.5970856, gradient norm = 0.0000001 (50 iterations in 0.310s)
# [t-SNE] Iteration 26300: error = 1.5968443, gradient norm = 0.0000001 (50 iterations in 0.281s)
# [t-SNE] Iteration 26350: error = 1.5965885, gradient norm = 0.0000001 (50 iterations in 0.255s)
# [t-SNE] Iteration 26400: error = 1.5963421, gradient norm = 0.0000001 (50 iterations in 0.406s)
# [t-SNE] Iteration 26450: error = 1.5961056, gradient norm = 0.0000001 (50 iterations in 0.438s)
# [t-SNE] Iteration 26500: error = 1.5958505, gradient norm = 0.0000001 (50 iterations in 0.331s)
# [t-SNE] Iteration 26550: error = 1.5954924, gradient norm = 0.0000001 (50 iterations in 0.301s)
# [t-SNE] Iteration 26600: error = 1.5952637, gradient norm = 0.0000001 (50 iterations in 0.322s)
# [t-SNE] Iteration 26650: error = 1.5950314, gradient norm = 0.0000001 (50 iterations in 0.312s)
# [t-SNE] Iteration 26700: error = 1.5948198, gradient norm = 0.0000001 (50 iterations in 0.328s)
# [t-SNE] Iteration 26750: error = 1.5945888, gradient norm = 0.0000001 (50 iterations in 0.307s)
# [t-SNE] Iteration 26800: error = 1.5944165, gradient norm = 0.0000001 (50 iterations in 0.295s)
# [t-SNE] Iteration 26850: error = 1.5942292, gradient norm = 0.0000001 (50 iterations in 0.282s)
# [t-SNE] Iteration 26900: error = 1.5939723, gradient norm = 0.0000001 (50 iterations in 0.272s)
# [t-SNE] Iteration 26950: error = 1.5937405, gradient norm = 0.0000001 (50 iterations in 0.261s)
# [t-SNE] Iteration 27000: error = 1.5935037, gradient norm = 0.0000001 (50 iterations in 0.260s)
# [t-SNE] Iteration 27050: error = 1.5932846, gradient norm = 0.0000001 (50 iterations in 0.249s)
# [t-SNE] Iteration 27100: error = 1.5929749, gradient norm = 0.0000001 (50 iterations in 0.260s)
# [t-SNE] Iteration 27150: error = 1.5927364, gradient norm = 0.0000001 (50 iterations in 0.277s)
# [t-SNE] Iteration 27200: error = 1.5925095, gradient norm = 0.0000001 (50 iterations in 0.289s)
# [t-SNE] Iteration 27250: error = 1.5922765, gradient norm = 0.0000001 (50 iterations in 0.298s)
# [t-SNE] Iteration 27300: error = 1.5920445, gradient norm = 0.0000001 (50 iterations in 0.334s)
# [t-SNE] Iteration 27350: error = 1.5918148, gradient norm = 0.0000001 (50 iterations in 0.379s)
# [t-SNE] Iteration 27400: error = 1.5915858, gradient norm = 0.0000001 (50 iterations in 0.301s)
# [t-SNE] Iteration 27450: error = 1.5913597, gradient norm = 0.0000001 (50 iterations in 0.307s)
# [t-SNE] Iteration 27500: error = 1.5911307, gradient norm = 0.0000001 (50 iterations in 0.303s)
# [t-SNE] Iteration 27550: error = 1.5909184, gradient norm = 0.0000001 (50 iterations in 0.307s)
# [t-SNE] Iteration 27600: error = 1.5906945, gradient norm = 0.0000001 (50 iterations in 0.287s)
# [t-SNE] Iteration 27650: error = 1.5904620, gradient norm = 0.0000001 (50 iterations in 0.296s)
# [t-SNE] Iteration 27700: error = 1.5902458, gradient norm = 0.0000001 (50 iterations in 0.308s)
# [t-SNE] Iteration 27750: error = 1.5900266, gradient norm = 0.0000001 (50 iterations in 0.286s)
# [t-SNE] Iteration 27800: error = 1.5897421, gradient norm = 0.0000001 (50 iterations in 0.312s)
# [t-SNE] Iteration 27850: error = 1.5895919, gradient norm = 0.0000001 (50 iterations in 0.319s)
# [t-SNE] Iteration 27900: error = 1.5893866, gradient norm = 0.0000001 (50 iterations in 0.262s)
# [t-SNE] Iteration 27950: error = 1.5892156, gradient norm = 0.0000001 (50 iterations in 0.283s)
# [t-SNE] Iteration 28000: error = 1.5889474, gradient norm = 0.0000001 (50 iterations in 0.292s)
# [t-SNE] Iteration 28050: error = 1.5887235, gradient norm = 0.0000001 (50 iterations in 0.279s)
# [t-SNE] Iteration 28100: error = 1.5884982, gradient norm = 0.0000001 (50 iterations in 0.269s)
# [t-SNE] Iteration 28150: error = 1.5883063, gradient norm = 0.0000001 (50 iterations in 0.268s)
# [t-SNE] Iteration 28200: error = 1.5880828, gradient norm = 0.0000001 (50 iterations in 0.343s)
# [t-SNE] Iteration 28250: error = 1.5878372, gradient norm = 0.0000001 (50 iterations in 0.347s)
# [t-SNE] Iteration 28300: error = 1.5876091, gradient norm = 0.0000001 (50 iterations in 0.462s)
# [t-SNE] Iteration 28350: error = 1.5873533, gradient norm = 0.0000001 (50 iterations in 0.335s)
# [t-SNE] Iteration 28400: error = 1.5871425, gradient norm = 0.0000001 (50 iterations in 0.263s)
# [t-SNE] Iteration 28450: error = 1.5869876, gradient norm = 0.0000001 (50 iterations in 0.261s)
# [t-SNE] Iteration 28500: error = 1.5867829, gradient norm = 0.0000001 (50 iterations in 0.273s)
# [t-SNE] Iteration 28550: error = 1.5866048, gradient norm = 0.0000001 (50 iterations in 0.280s)
# [t-SNE] Iteration 28600: error = 1.5863245, gradient norm = 0.0000001 (50 iterations in 0.309s)
# [t-SNE] Iteration 28650: error = 1.5860959, gradient norm = 0.0000001 (50 iterations in 0.308s)
# [t-SNE] Iteration 28700: error = 1.5859125, gradient norm = 0.0000001 (50 iterations in 0.287s)
# [t-SNE] Iteration 28750: error = 1.5856937, gradient norm = 0.0000001 (50 iterations in 0.268s)
# [t-SNE] Iteration 28800: error = 1.5854708, gradient norm = 0.0000001 (50 iterations in 0.349s)
# [t-SNE] Iteration 28850: error = 1.5852681, gradient norm = 0.0000001 (50 iterations in 0.309s)
# [t-SNE] Iteration 28900: error = 1.5850632, gradient norm = 0.0000001 (50 iterations in 0.295s)
# [t-SNE] Iteration 28950: error = 1.5847228, gradient norm = 0.0000001 (50 iterations in 0.283s)
# [t-SNE] Iteration 29000: error = 1.5844525, gradient norm = 0.0000001 (50 iterations in 0.265s)
# [t-SNE] Iteration 29050: error = 1.5842336, gradient norm = 0.0000001 (50 iterations in 0.272s)
# [t-SNE] Iteration 29100: error = 1.5840098, gradient norm = 0.0000001 (50 iterations in 0.273s)
# [t-SNE] Iteration 29150: error = 1.5837766, gradient norm = 0.0000001 (50 iterations in 0.346s)
# [t-SNE] Iteration 29200: error = 1.5835555, gradient norm = 0.0000001 (50 iterations in 0.418s)
# [t-SNE] Iteration 29250: error = 1.5834291, gradient norm = 0.0000001 (50 iterations in 0.316s)
# [t-SNE] Iteration 29300: error = 1.5832012, gradient norm = 0.0000001 (50 iterations in 0.309s)
# [t-SNE] Iteration 29350: error = 1.5830803, gradient norm = 0.0000001 (50 iterations in 0.265s)
# [t-SNE] Iteration 29400: error = 1.5828173, gradient norm = 0.0000001 (50 iterations in 0.262s)
# [t-SNE] Iteration 29450: error = 1.5823544, gradient norm = 0.0000001 (50 iterations in 0.248s)
# [t-SNE] Iteration 29500: error = 1.5821347, gradient norm = 0.0000001 (50 iterations in 0.282s)
# [t-SNE] Iteration 29550: error = 1.5819050, gradient norm = 0.0000001 (50 iterations in 0.284s)
# [t-SNE] Iteration 29600: error = 1.5816727, gradient norm = 0.0000001 (50 iterations in 0.270s)
# [t-SNE] Iteration 29650: error = 1.5814799, gradient norm = 0.0000001 (50 iterations in 0.264s)
# [t-SNE] Iteration 29700: error = 1.5812533, gradient norm = 0.0000001 (50 iterations in 0.264s)
# [t-SNE] Iteration 29750: error = 1.5810250, gradient norm = 0.0000001 (50 iterations in 0.282s)
# [t-SNE] Iteration 29800: error = 1.5807770, gradient norm = 0.0000001 (50 iterations in 0.296s)
# [t-SNE] Iteration 29850: error = 1.5805502, gradient norm = 0.0000001 (50 iterations in 0.319s)
# [t-SNE] Iteration 29900: error = 1.5803179, gradient norm = 0.0000001 (50 iterations in 0.325s)
# [t-SNE] Iteration 29950: error = 1.5802573, gradient norm = 0.0000001 (50 iterations in 0.323s)
# [t-SNE] Iteration 30000: error = 1.5800277, gradient norm = 0.0000001 (50 iterations in 0.295s)
# [t-SNE] KL divergence after 30000 iterations: 1.580028
# --- 187.3721833229065 seconds ---

# %%
df=pd.DataFrame(all_word_vectors_matrix_3d,columns=['X','Y', 'Z'])

df.head(10)

train.head()

df.reset_index(drop=True, inplace=True)
train.reset_index(drop=True, inplace=True)

# %%
three_dimensional_songs = pd.concat([train, df], axis=1)

three_dimensional_songs.head()
# Out:
#                                            NEW_TITLE     SECTION  \
# 0                        ¡Pedro, Pedro, encadénanos!     opinion
# 1  MasterChef 8 y la rebelión que acabó en una cr...  television
# 2  El Gobierno gana poder en el deporte y lleva a...    deportes
# 3  Muere José María Castillo, productor ejecutivo...  television
# 4  El Gobierno quita el límite de suspensos que f...      espana
#
#                                          SECTION_URL  \
# 0  https://www.elmundo.es/opinion.html?intcmp=MEN...
# 1  https://www.elmundo.es/television.html?intcmp=...
# 2  https://www.elmundo.es/deportes.html?intcmp=ME...
# 3  https://www.elmundo.es/television.html?intcmp=...
# 4  https://www.elmundo.es/espana.html?intcmp=MENU...
#
#                                              NEW_URL  \
# 0  https://www.elmundo.es/opinion/2020/04/15/5e97...
# 1  https://www.elmundo.es/television/momentvs/202...
# 2  https://www.elmundo.es/deportes/futbol/primera...
# 3  https://www.elmundo.es/television/2020/04/12/5...
# 4  https://www.elmundo.es/espana/2020/04/24/5ea2b...
#
#                                                  NEW  \
# 0  Al final el pobre Sánchez no va a tener más re...
# 1  "Cuenta la leyenda que allá por el 2020, en pl...
# 2  "Los pactos alcanzados en la reunión entre Ire...
# 3  "Este domingo ha fallecido José María Castillo...
# 4  "El Gobierno ha quitado ""de forma excepcional...
#
#                                          news_vector            X  \
# 0  [[-0.018448656, 0.101849996, 0.18082964, -0.16...   -83.147209
# 1  [[-0.037350487, 0.107858576, 0.19142526, -0.17...  1095.219971
# 2  [[-0.040540792, 0.10750827, 0.17678349, -0.155...   118.848640
# 3  [[0.0018487575, 0.11295477, 0.14102325, -0.147...  1025.276245
# 4  [[-0.062308613, 0.13607141, 0.18420309, -0.187...  -136.912872
#
#              Y           Z
# 0  1204.362061 -931.738831
# 1  -173.943100  440.944824
# 2   613.045654 -519.768250
# 3  -439.361176 -928.734009
# 4   350.793976   99.948891

# %%
import plotly.express as px

fig = px.scatter_3d(three_dimensional_songs, x='X', y='Y', z='Z',
              color='SECTION')
fig.show()
# Out:
# <div>
#
#
#             <div id="1c9e3ea9-efd2-483e-a395-d0e63d58b972" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1c9e3ea9-efd2-483e-a395-d0e63d58b972")) {
#                     Plotly.newPlot(
#                         '1c9e3ea9-efd2-483e-a395-d0e63d58b972',
#                         [{"hovertemplate": "SECTION=opinion<br>X=%{x}<br>Y=%{y}<br>Z=%{z}<extra></extra>", "legendgroup": "opinion", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "opinion", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-83.14720916748047, -154.8691864013672, 377.552978515625, -358.6958312988281, -37.52333068847656, -282.0755920410156, -53.300498962402344, 9.155391693115234, -621.5659790039062, -1114.000244140625, 503.515869140625, -164.6882781982422, -906.69189453125, -148.2108612060547, 538.2640991210938, 555.1302490234375, -942.6063232421875, 1080.1463623046875, 528.99853515625, -885.86181640625, 229.86770629882812, 347.369140625, 647.9027709960938, -30.61899185180664, -1140.83203125, -263.9856872558594, -575.7467041015625, 186.2236785888672, 740.4588623046875, -145.37945556640625, -99.81861877441406, 1109.285888671875, -50.62575912475586, -275.70989990234375, 203.8675537109375, 394.33856201171875, 1085.0836181640625, 504.055908203125, -635.8719482421875, 893.8639526367188, -1303.6337890625, 690.047119140625, -806.3123168945312, 435.4853820800781, 72.48918151855469, -367.3868408203125, 258.79595947265625, -632.4205932617188, 285.1090393066406, -333.9552307128906, 150.7578887939453, 940.9072265625, -438.46405029296875, -209.18460083007812, 57.980411529541016, 906.6882934570312, -442.6881103515625], "y": [1204.362060546875, 614.8862915039062, 19.488943099975586, -671.5409545898438, 721.5107421875, 1303.888427734375, 283.6988525390625, 462.37896728515625, 1331.2965087890625, -418.3205261230469, 126.65615844726562, 502.0395812988281, 551.96484375, 914.5927124023438, 461.9419860839844, 832.8599243164062, -693.4254760742188, 315.15478515625, 253.49583435058594, -968.3533325195312, 3.7987425327301025, 255.66009521484375, 337.26873779296875, 520.0745239257812, 405.8140869140625, -444.5041809082031, 29.167591094970703, 519.1920776367188, 1006.0944213867188, 596.8648681640625, 847.4203491210938, -387.88751220703125, -1053.552001953125, 947.5646362304688, 459.95465087890625, 202.27114868164062, 667.87451171875, 656.5210571289062, 392.07427978515625, 426.0291442871094, 361.34649658203125, 957.3045043945312, 1018.121337890625, -362.08734130859375, 970.9200439453125, -267.0945129394531, 421.2021789550781, -137.1824951171875, -362.40045166015625, 173.79281616210938, 859.63623046875, -281.8919982910156, 742.084228515625, -477.0234375, 600.3289794921875, 998.8497924804688, 394.2392883300781], "z": [-931.7388305664062, 148.48915100097656, -983.0745239257812, -1170.86328125, -240.7373809814453, -259.0206604003906, -1131.802001953125, -204.30560302734375, 21.77553939819336, -19.947021484375, -571.8055419921875, -108.59469604492188, -858.3093872070312, 201.09585571289062, -1126.1544189453125, -304.0490417480469, 433.97900390625, -62.83774185180664, -761.5253295898438, 766.3530883789062, -1141.5589599609375, 1159.1190185546875, 1179.4332275390625, 379.27386474609375, 193.08689880371094, 1280.0423583984375, -827.0827026367188, -728.4708251953125, -767.5460815429688, 627.0845336914062, -835.2962036132812, 823.6596069335938, 114.9926528930664, 747.6632690429688, 990.2077026367188, 94.08843231201172, -672.5062255859375, -1184.4517822265625, 428.5445556640625, 896.177490234375, -58.655975341796875, -549.274658203125, 432.8483581542969, 79.20247650146484, 945.00634765625, -1312.1385498046875, -1008.8370361328125, 1234.1529541015625, -126.59939575195312, 510.5635070800781, -1080.5316162109375, -74.4212875366211, 674.792236328125, -1001.7108154296875, 244.05337524414062, -321.987060546875, -179.55938720703125]}, {"hovertemplate": "SECTION=television<br>X=%{x}<br>Y=%{y}<br>Z=%{z}<extra></extra>", "legendgroup": "television", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "television", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1095.219970703125, 1025.2762451171875, -1151.766357421875, 506.05633544921875, -639.7374877929688, -94.478500 ...

# %% [markdown]
# #### El análisis 3D ha dado sus frutos y se observa como en este caso se agrupan más secciones, como la sección internacional, la de cultura, la de España, la de deportes o la de tecnología. Como en los casos anteriores, no están claramente separadas, pero las noticias pertenecientes a una misma sección están cerca unas de las otras.
